# %%
# !pip3 install -q --upgrade pip
# !pip3 install -q pandas numpy matplotlib seaborn openpyxl climateserv requests netCDF4 xarray pyproj

# %%
import os
import sys
import numpy as np
import xarray as xr
import pandas as pd
import netCDF4 as nc
import seaborn as sns
import geopandas as gpd
from typing import List
from pathlib import Path
import matplotlib.pyplot as plt
import climateservaccess as ca
from scipy.spatial import KDTree
from shapely.geometry import Point

# Calculate the path to the scripts folder relative to the current notebook.
scripts_dir = Path("../../").resolve()

# Add the scripts directory to the sys.path if it's not already there.
if str(scripts_dir) not in sys.path:
    sys.path.append(str(scripts_dir))

# Define datatype and region
datatype_nums = [662, 663]
datatypes = [ca.datatypeDict[datatype_num] for datatype_num in datatype_nums]
REGION = "gambia"
DATE = "12-01-2023"
DATATYPE = "LIS_Streamflow"
datatypes
# Out:
# ['LIS_Baseflow', 'LIS_Runoff']

# %% [markdown]
# ### We create a code to know what is inside the file .nc, wich variables how many data, etc.

# %%
def analyze_nasadem_file(file_path: str) -> list:
    """
    Analyze a NetCDF file and print out its contents, such as variable names,
    dimensions, and min/max values for longitude and latitude.

    Args:
    file_path (str): The path to the NASADEM NetCDF file.
    """
    # Check if the file exists
    if not os.path.exists(file_path):
        print(f"File not found: {file_path}")
        return
    
    # Open the NetCDF file
    dataset = nc.Dataset(file_path, 'r')

    # Print general information about the file
    print('')
    print(f"Analyzing file: {file_path}")
    print("Variables in this file:")
    for var in dataset.variables:
        print(f" - {var}: {dataset.variables[var].dimensions}, {dataset.variables[var].shape}")

    # Check for common variables like longitude and latitude
    if 'lon' in dataset.variables and 'lat' in dataset.variables:
        lon = dataset.variables['lon'][:]
        lat = dataset.variables['lat'][:]
        print(f"Longitude range: {np.min(lon)} to {np.max(lon)}")
        print(f"Latitude range: {np.min(lat)} to {np.max(lat)}")
    
    return list(dataset.variables.keys())

    # Close the dataset
    dataset.close()

# Paths to your files
file_paths = [
    f'../../data/original_data/climateserv/area_of_interest_1/{DATE}/{datatype}.nc' for datatype in datatypes
]

# Analyze each file
for path in file_paths:
    variables = analyze_nasadem_file(file_path=path)
# Out:
# Analyzing file: ../../data/original_data/climateserv/area_of_interest_1/12-01-2023/LIS_Baseflow.nc
# Variables in this file:
#  - time: ('time',), (1,)
#  - latitude: ('latitude',), (15,)
#  - longitude: ('longitude',), (9,)
#  - Baseflow: ('time', 'latitude', 'longitude'), (1, 15, 9)
#
# Analyzing file: ../../data/original_data/climateserv/area_of_interest_1/12-01-2023/LIS_Runoff.nc
# Variables in this file:
#  - time: ('time',), (1,)
#  - latitude: ('latitude',), (15,)
#  - longitude: ('longitude',), (9,)
#  - Runoff: ('time', 'latitude', 'longitude'), (1, 15, 9)

# %% [markdown]
# ### After we know what its inside the file, we process him, converting into a DataFrame and saving as CSV.

# %%
def load_data_to_dataframe(file_path: str) -> pd.DataFrame:
    """
    Loads data from a NetCDF file, removes the 'time' column, 
    drops rows with NaN in last (data) column, and converts it to a Pandas DataFrame.

    Args:
        file_path (str): Path to the NetCDF file.

    Returns:
        pd.DataFrame: DataFrame containing the data with the modifications applied.
    """
    # Open the NetCDF file
    ds = xr.open_dataset(file_path)

    # Get the name of the data variable from this netcdf, not variables
    data_var_name = list(ds.data_vars)[0]
    print(f"Data variable name: {data_var_name}")
    
    # Select data_var_name name and the first time point 
    data = ds[data_var_name][0]
    

    # Convert to DataFrame
    df = data.to_dataframe().reset_index()

    # Drop the 'time' column
    df = df.drop(columns=['time'])

    # Drop rows where data_var_name is NaN
    df = df.dropna(subset=[data_var_name])

    return df

def save_dataframe_to_csv(dataframe: pd.DataFrame, output_path: str) -> None:
    """
    Saves the given DataFrame to a CSV file.

    Args:
        dataframe (pd.DataFrame): DataFrame to be saved.
        output_path (str): Path where the CSV file will be saved.
    """
    # Ensure the output directory exists
    os.makedirs(os.path.dirname(output_path), exist_ok=True)
    
    # Save the DataFrame to a CSV file
    dataframe.to_csv(output_path, index=False)

# %%
# Paths to your files
file_paths = [
    f'../../data/original_data/climateserv/area_of_interest_1/{DATE}/{datatype}.nc' for datatype in datatypes
]

# Merge all the data into a single DataFrame
df = pd.DataFrame()

for file_path in file_paths:
    # Load the data into a DataFrame
    temp_df = load_data_to_dataframe(file_path=file_path)

    # Latitude and longitude merge
    df['lat'] = temp_df['latitude']
    df['lon'] = temp_df['longitude']
    
    # Merge last column
    data_var_name = list(temp_df)[-1]
    df[data_var_name] = temp_df[data_var_name]
    
df.head()
# Out:
# Data variable name: Baseflow
# Data variable name: Runoff
#        lat     lon  Baseflow        Runoff
# 20  13.135 -16.755  0.001112  0.000000e+00
# 21  13.135 -16.725  0.106376  0.000000e+00
# 29  13.165 -16.755  0.104411  8.586881e-12
# 30  13.165 -16.725  0.084890  4.293441e-12
# 31  13.165 -16.695  0.110308  1.853986e-12

# %% [markdown]
# ### We will visualize the data

# %%
# List of soil moisture columns to plot, excluding 'lat' and 'lon'
columns_to_plot = [col for col in df.columns if col not in ['lat', 'lon']]

# Create a figure with subplots
fig, axes = plt.subplots(nrows=len(columns_to_plot), ncols=1, figsize=(10, 8))

# Iterate over the columns and create a histogram for each
for i, col in enumerate(columns_to_plot):
    axes[i].hist(df[col], bins=20, alpha=0.7, color='blue')
    axes[i].set_title(f'Histogram of {col}')
    axes[i].set_xlabel('Value')
    axes[i].set_ylabel('Frequency')

# Adjust the layout
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# ##### Note: Runoff values are very small, approx zero

# %% [markdown]
# ### Now, we will combine the runoff and baseflow data into streamflow

# %%
# Combine multiple data columns into a single column and put into df_climateserv

df[DATATYPE] = np.sum(df[columns_to_plot], axis=1)
df_climateserv = df[['lat', 'lon', DATATYPE]]

# Plot the combined column
df[DATATYPE].hist(bins=20, alpha=0.7, color='blue', figsize=(10, 3))
plt.title(f'Histogram of {DATATYPE}')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.xlim(0, 0.5)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Here, we will merge this data with the dataframe we have with information of the differents points with lat and long.

# %%
df = pd.read_csv("../../data/final_dataset/processed_data/merged_data.csv")

df
# Out:
#             Date       long        lat  Drainage_density  Slope_tif2  \
# 0     12-01-2023 -16.670616  13.488346         13.499496    0.000000
# 1     12-01-2023 -16.665998  13.488376         14.573664    0.000000
# 2     12-01-2023 -16.684438  13.483734         15.609715    0.000000
# 3     12-01-2023 -16.679820  13.483765         13.571120    0.000000
# 4     12-01-2023 -16.675202  13.483796         13.922873    0.000000
# ...          ...        ...        ...               ...         ...
# 2869  12-01-2023 -16.746177  13.076569         34.977886    1.642019
# 2870  12-01-2023 -16.741567  13.076600         44.632805    2.321531
# 2871  12-01-2023 -16.736957  13.076631         49.922588    2.706814
# 2872  12-01-2023 -16.732347  13.076662         49.457001    0.734494
# 2873  12-01-2023 -16.727737  13.076693         48.282181    0.929039
#
#       Hydrogeo  Curvatu_tif2  NASADEM_HGT DepthToGroundwater  NASA_IMERG_Late  \
# 0          5.0 -0.000000e+00          0.0                0-7              0.0
# 1          5.0 -0.000000e+00          0.0                0-7              0.0
# 2          5.0 -0.000000e+00          0.0                0-7              0.0
# 3          5.0 -0.000000e+00          0.0                0-7              0.0
# 4          5.0 -0.000000e+00          0.0                0-7              0.0
# ...        ...           ...          ...                ...              ...
# 2869       5.0  2.592000e+09          9.0                0-7              0.0
# 2870       5.0 -5.184000e+09          2.0                0-7              0.0
# 2871       5.0  3.888000e+09          2.0                0-7              0.0
# 2872       5.0 -3.888000e+09          3.0                0-7              0.0
# 2873       5.0 -1.296000e+09          4.0                0-7              0.0
#
#         LIS_ET  LIS_Soil_Moisture_Combined
# 0     1.766242                    0.209369
# 1     1.766242                    0.209369
# 2     1.252523                    0.220998
# 3     1.766242                    0.209369
# 4     1.766242                    0.209369
# ...        ...                         ...
# 2869  2.358303                    0.295715
# 2870  2.358303                    0.295715
# 2871  2.000822                    0.274988
# 2872  2.000822                    0.274988
# 2873  2.000822                    0.274988
#
# [2874 rows x 12 columns]

# %%
from scipy.spatial import cKDTree

# Build a KDTree for efficient nearest neighbor search
tree = cKDTree(df_climateserv[['lat', 'lon']])

# New column to store NASADEM_HGT values
df[DATATYPE] = 0.0

# Iterate over each row in df to find the nearest neighbor in df_climateserv
for index, row in df.iterrows():
    # Query the tree for the nearest neighbor
    distance, nearest_idx = tree.query([row['lat'], row['long']], k=1)
    
    # Get the NASADEM_HGT value of the nearest neighbor
    nearest_nasadem_hgt = df_climateserv.iloc[nearest_idx][DATATYPE]
    
    # Assign the value to the new column in df
    df.at[index, DATATYPE] = nearest_nasadem_hgt

    # Optional: print progress
    print(f"Processed row {index + 1}/{len(df)}")

# df now has the new column DATATYPE populated with values
# Out:
# Processed row 1/2874
# Processed row 2/2874
# Processed row 3/2874
# Processed row 4/2874
# Processed row 5/2874
# Processed row 6/2874
# Processed row 7/2874
# Processed row 8/2874
# Processed row 9/2874
# Processed row 10/2874
# Processed row 11/2874
# Processed row 12/2874
# Processed row 13/2874
# Processed row 14/2874
# Processed row 15/2874
# Processed row 16/2874
# Processed row 17/2874
# Processed row 18/2874
# Processed row 19/2874
# Processed row 20/2874
# Processed row 21/2874
# Processed row 22/2874
# Processed row 23/2874
# Processed row 24/2874
# Processed row 25/2874
# Processed row 26/2874
# Processed row 27/2874
# Processed row 28/2874
# Processed row 29/2874
# Processed row 30/2874
# Processed row 31/2874
# Processed row 32/2874
# Processed row 33/2874
# Processed row 34/2874
# Processed row 35/2874
# Processed row 36/2874
# Processed row 37/2874
# Processed row 38/2874
# Processed row 39/2874
# Processed row 40/2874
# Processed row 41/2874
# Processed row 42/2874
# Processed row 43/2874
# Processed row 44/2874
# Processed row 45/2874
# Processed row 46/2874
# Processed row 47/2874
# Processed row 48/2874
# Processed row 49/2874
# Processed row 50/2874
# Processed row 51/2874
# Processed row 52/2874
# Processed row 53/2874
# Processed row 54/2874
# Processed row 55/2874
# Processed row 56/2874
# Processed row 57/2874
# Processed row 58/2874
# Processed row 59/2874
# Processed row 60/2874
# Processed row 61/2874
# Processed row 62/2874
# Processed row 63/2874
# Processed row 64/2874
# Processed row 65/2874
# Processed row 66/2874
# Processed row 67/2874
# Processed row 68/2874
# Processed row 69/2874
# Processed row 70/2874
# Processed row 71/2874
# Processed row 72/2874
# Processed row 73/2874
# Processed row 74/2874
# Processed row 75/2874
# Processed row 76/2874
# Processed row 77/2874
# Processed row 78/2874
# Processed row 79/2874
# Processed row 80/2874
# Processed row 81/2874
# Processed row 82/2874
# Processed row 83/2874
# Processed row 84/2874
# Processed row 85/2874
# Processed row 86/2874
# Processed row 87/2874
# Processed row 88/2874
# Processed row 89/2874
# Processed row 90/2874
# Processed row 91/2874
# Processed row 92/2874
# Processed row 93/2874
# Processed row 94/2874
# Processed row 95/2874
# Processed row 96/2874
# Processed row 97/2874
# Processed row 98/2874
# Processed row 99/2874
# Processed row 100/2874
# Processed row 101/2874
# Processed row 102/2874
# Processed row 103/2874
# Processed row 104/2874
# Processed row 105/2874
# Processed row 106/2874
# Processed row 107/2874
# Processed row 108/2874
# Processed row 109/2874
# Processed row 110/2874
# Processed row 111/2874
# Processed row 112/2874
# Processed row 113/2874
# Processed row 114/2874
# Processed row 115/2874
# Processed row 116/2874
# Processed row 117/2874
# Processed row 118/2874
# Processed row 119/2874
# Processed row 120/2874
# Processed row 121/2874
# Processed row 122/2874
# Processed row 123/2874
# Processed row 124/2874
# Processed row 125/2874
# Processed row 126/2874
# Processed row 127/2874
# Processed row 128/2874
# Processed row 129/2874
# Processed row 130/2874
# Processed row 131/2874
# Processed row 132/2874
# Processed row 133/2874
# Processed row 134/2874
# Processed row 135/2874
# Processed row 136/2874
# Processed row 137/2874
# Processed row 138/2874
# Processed row 139/2874
# Processed row 140/2874
# Processed row 141/2874
# Processed row 142/2874
# Processed row 143/2874
# Processed row 144/2874
# Processed row 145/2874
# Processed row 146/2874
# Processed row 147/2874
# Processed row 148/2874
# Processed row 149/2874
# Processed row 150/2874
# Processed row 151/2874
# Processed row 152/2874
# Processed row 153/2874
# Processed row 154/2874
# Processed row 155/2874
# Processed row 156/2874
# Processed row 157/2874
# Processed row 158/2874
# Processed row 159/2874
# Processed row 160/2874
# Processed row 161/2874
# Processed row 162/2874
# Processed row 163/2874
# Processed row 164/2874
# Processed row 165/2874
# Processed row 166/2874
# Processed row 167/2874
# Processed row 168/2874
# Processed row 169/2874
# Processed row 170/2874
# Processed row 171/2874
# Processed row 172/2874
# Processed row 173/2874
# Processed row 174/2874
# Processed row 175/2874
# Processed row 176/2874
# Processed row 177/2874
# Processed row 178/2874
# Processed row 179/2874
# Processed row 180/2874
# Processed row 181/2874
# Processed row 182/2874
# Processed row 183/2874
# Processed row 184/2874
# Processed row 185/2874
# Processed row 186/2874
# Processed row 187/2874
# Processed row 188/2874
# Processed row 189/2874
# Processed row 190/2874
# Processed row 191/2874
# Processed row 192/2874
# Processed row 193/2874
# Processed row 194/2874
# Processed row 195/2874
# Processed row 196/2874
# Processed row 197/2874
# Processed row 198/2874
# Processed row 199/2874
# Processed row 200/2874
# Processed row 201/2874
# Processed row 202/2874
# Processed row 203/2874
# Processed row 204/2874
# Processed row 205/2874
# Processed row 206/2874
# Processed row 207/2874
# Processed row 208/2874
# Processed row 209/2874
# Processed row 210/2874
# Processed row 211/2874
# Processed row 212/2874
# Processed row 213/2874
# Processed row 214/2874
# Processed row 215/2874
# Processed row 216/2874
# Processed row 217/2874
# Processed row 218/2874
# Processed row 219/2874
# Processed row 220/2874
# Processed row 221/2874
# Processed row 222/2874
# Processed row 223/2874
# Processed row 224/2874
# Processed row 225/2874
# Processed row 226/2874
# Processed row 227/2874
# Processed row 228/2874
# Processed row 229/2874
# Processed row 230/2874
# Processed row 231/2874
# Processed row 232/2874
# Processed row 233/2874
# Processed row 234/2874
# Processed row 235/2874
# Processed row 236/2874
# Processed row 237/2874
# Processed row 238/2874
# Processed row 239/2874
# Processed row 240/2874
# Processed row 241/2874
# Processed row 242/2874
# Processed row 243/2874
# Processed row 244/2874
# Processed row 245/2874
# Processed row 246/2874
# Processed row 247/2874
# Processed row 248/2874
# Processed row 249/2874
# Processed row 250/2874
# Processed row 251/2874
# Processed row 252/2874
# Processed row 253/2874
# Processed row 254/2874
# Processed row 255/2874
# Processed row 256/2874
# Processed row 257/2874
# Processed row 258/2874
# Processed row 259/2874
# Processed row 260/2874
# Processed row 261/2874
# Processed row 262/2874
# Processed row 263/2874
# Processed row 264/2874
# Processed row 265/2874
# Processed row 266/2874
# Processed row 267/2874
# Processed row 268/2874
# Processed row 269/2874
# Processed row 270/2874
# Processed row 271/2874
# Processed row 272/2874
# Processed row 273/2874
# Processed row 274/2874
# Processed row 275/2874
# Processed row 276/2874
# Processed row 277/2874
# Processed row 278/2874
# Processed row 279/2874
# Processed row 280/2874
# Processed row 281/2874
# Processed row 282/2874
# Processed row 283/2874
# Processed row 284/2874
# Processed row 285/2874
# Processed row 286/2874
# Processed row 287/2874
# Processed row 288/2874
# Processed row 289/2874
# Processed row 290/2874
# Processed row 291/2874
# Processed row 292/2874
# Processed row 293/2874
# Processed row 294/2874
# Processed row 295/2874
# Processed row 296/2874
# Processed row 297/2874
# Processed row 298/2874
# Processed row 299/2874
# Processed row 300/2874
# Processed row 301/2874
# Processed row 302/2874
# Processed row 303/2874
# Processed row 304/2874
# Processed row 305/2874
# Processed row 306/2874
# Processed row 307/2874
# Processed row 308/2874
# Processed row 309/2874
# Processed row 310/2874
# Processed row 311/2874
# Processed row 312/2874
# Processed row 313/2874
# Processed row 314/2874
# Processed row 315/2874
# Processed row 316/2874
# Processed row 317/2874
# Processed row 318/2874
# Processed row 319/2874
# Processed row 320/2874
# Processed row 321/2874
# Processed row 322/2874
# Processed row 323/2874
# Processed row 324/2874
# Processed row 325/2874
# Processed row 326/2874
# Processed row 327/2874
# Processed row 328/2874
# Processed row 329/2874
# Processed row 330/2874
# Processed row 331/2874
# Processed row 332/2874
# Processed row 333/2874
# Processed row 334/2874
# Processed row 335/2874
# Processed row 336/2874
# Processed row 337/2874
# Processed row 338/2874
# Processed row 339/2874
# Processed row 340/2874
# Processed row 341/2874
# Processed row 342/2874
# Processed row 343/2874
# Processed row 344/2874
# Processed row 345/2874
# Processed row 346/2874
# Processed row 347/2874
# Processed row 348/2874
# Processed row 349/2874
# Processed row 350/2874
# Processed row 351/2874
# Processed row 352/2874
# Processed row 353/2874
# Processed row 354/2874
# Processed row 355/2874
# Processed row 356/2874
# Processed row 357/2874
# Processed row 358/2874
# Processed row 359/2874
# Processed row 360/2874
# Processed row 361/2874
# Processed row 362/2874
# Processed row 363/2874
# Processed row 364/2874
# Processed row 365/2874
# Processed row 366/2874
# Processed row 367/2874
# Processed row 368/2874
# Processed row 369/2874
# Processed row 370/2874
# Processed row 371/2874
# Processed row 372/2874
# Processed row 373/2874
# Processed row 374/2874
# Processed row 375/2874
# Processed row 376/2874
# Processed row 377/2874
# Processed row 378/2874
# Processed row 379/2874
# Processed row 380/2874
# Processed row 381/2874
# Processed row 382/2874
# Processed row 383/2874
# Processed row 384/2874
# Processed row 385/2874
# Processed row 386/2874
# Processed row 387/2874
# Processed row 388/2874
# Processed row 389/2874
# Processed row 390/2874
# Processed row 391/2874
# Processed row 392/2874
# Processed row 393/2874
# Processed row 394/2874
# Processed row 395/2874
# Processed row 396/2874
# Processed row 397/2874
# Processed row 398/2874
# Processed row 399/2874
# Processed row 400/2874
# Processed row 401/2874
# Processed row 402/2874
# Processed row 403/2874
# Processed row 404/2874
# Processed row 405/2874
# Processed row 406/2874
# Processed row 407/2874
# Processed row 408/2874
# Processed row 409/2874
# Processed row 410/2874
# Processed row 411/2874
# Processed row 412/2874
# Processed row 413/2874
# Processed row 414/2874
# Processed row 415/2874
# Processed row 416/2874
# Processed row 417/2874
# Processed row 418/2874
# Processed row 419/2874
# Processed row 420/2874
# Processed row 421/2874
# Processed row 422/2874
# Processed row 423/2874
# Processed row 424/2874
# Processed row 425/2874
# Processed row 426/2874
# Processed row 427/2874
# Processed row 428/2874
# Processed row 429/2874
# Processed row 430/2874
# Processed row 431/2874
# Processed row 432/2874
# Processed row 433/2874
# Processed row 434/2874
# Processed row 435/2874
# Processed row 436/2874
# Processed row 437/2874
# Processed row 438/2874
# Processed row 439/2874
# Processed row 440/2874
# Processed row 441/2874
# Processed row 442/2874
# Processed row 443/2874
# Processed row 444/2874
# Processed row 445/2874
# Processed row 446/2874
# Processed row 447/2874
# Processed row 448/2874
# Processed row 449/2874
# Processed row 450/2874
# Processed row 451/2874
# Processed row 452/2874
# Processed row 453/2874
# Processed row 454/2874
# Processed row 455/2874
# Processed row 456/2874
# Processed row 457/2874
# Processed row 458/2874
# Processed row 459/2874
# Processed row 460/2874
# Processed row 461/2874
# Processed row 462/2874
# Processed row 463/2874
# Processed row 464/2874
# Processed row 465/2874
# Processed row 466/2874
# Processed row 467/2874
# Processed row 468/2874
# Processed row 469/2874
# Processed row 470/2874
# Processed row 471/2874
# Processed row 472/2874
# Processed row 473/2874
# Processed row 474/2874
# Processed row 475/2874
# Processed row 476/2874
# Processed row 477/2874
# Processed row 478/2874
# Processed row 479/2874
# Processed row 480/2874
# Processed row 481/2874
# Processed row 482/2874
# Processed row 483/2874
# Processed row 484/2874
# Processed row 485/2874
# Processed row 486/2874
# Processed row 487/2874
# Processed row 488/2874
# Processed row 489/2874
# Processed row 490/2874
# Processed row 491/2874
# Processed row 492/2874
# Processed row 493/2874
# Processed row 494/2874
# Processed row 495/2874
# Processed row 496/2874
# Processed row 497/2874
# Processed row 498/2874
# Processed row 499/2874
# Processed row 500/2874
# Processed row 501/2874
# Processed row 502/2874
# Processed row 503/2874
# Processed row 504/2874
# Processed row 505/2874
# Processed row 506/2874
# Processed row 507/2874
# Processed row 508/2874
# Processed row 509/2874
# Processed row 510/2874
# Processed row 511/2874
# Processed row 512/2874
# Processed row 513/2874
# Processed row 514/2874
# Processed row 515/2874
# Processed row 516/2874
# Processed row 517/2874
# Processed row 518/2874
# Processed row 519/2874
# Processed row 520/2874
# Processed row 521/2874
# Processed row 522/2874
# Processed row 523/2874
# Processed row 524/2874
# Processed row 525/2874
# Processed row 526/2874
# Processed row 527/2874
# Processed row 528/2874
# Processed row 529/2874
# Processed row 530/2874
# Processed row 531/2874
# Processed row 532/2874
# Processed row 533/2874
# Processed row 534/2874
# Processed row 535/2874
# Processed row 536/2874
# Processed row 537/2874
# Processed row 538/2874
# Processed row 539/2874
# Processed row 540/2874
# Processed row 541/2874
# Processed row 542/2874
# Processed row 543/2874
# Processed row 544/2874
# Processed row 545/2874
# Processed row 546/2874
# Processed row 547/2874
# Processed row 548/2874
# Processed row 549/2874
# Processed row 550/2874
# Processed row 551/2874
# Processed row 552/2874
# Processed row 553/2874
# Processed row 554/2874
# Processed row 555/2874
# Processed row 556/2874
# Processed row 557/2874
# Processed row 558/2874
# Processed row 559/2874
# Processed row 560/2874
# Processed row 561/2874
# Processed row 562/2874
# Processed row 563/2874
# Processed row 564/2874
# Processed row 565/2874
# Processed row 566/2874
# Processed row 567/2874
# Processed row 568/2874
# Processed row 569/2874
# Processed row 570/2874
# Processed row 571/2874
# Processed row 572/2874
# Processed row 573/2874
# Processed row 574/2874
# Processed row 575/2874
# Processed row 576/2874
# Processed row 577/2874
# Processed row 578/2874
# Processed row 579/2874
# Processed row 580/2874
# Processed row 581/2874
# Processed row 582/2874
# Processed row 583/2874
# Processed row 584/2874
# Processed row 585/2874
# Processed row 586/2874
# Processed row 587/2874
# Processed row 588/2874
# Processed row 589/2874
# Processed row 590/2874
# Processed row 591/2874
# Processed row 592/2874
# Processed row 593/2874
# Processed row 594/2874
# Processed row 595/2874
# Processed row 596/2874
# Processed row 597/2874
# Processed row 598/2874
# Processed row 599/2874
# Processed row 600/2874
# Processed row 601/2874
# Processed row 602/2874
# Processed row 603/2874
# Processed row 604/2874
# Processed row 605/2874
# Processed row 606/2874
# Processed row 607/2874
# Processed row 608/2874
# Processed row 609/2874
# Processed row 610/2874
# Processed row 611/2874
# Processed row 612/2874
# Processed row 613/2874
# Processed row 614/2874
# Processed row 615/2874
# Processed row 616/2874
# Processed row 617/2874
# Processed row 618/2874
# Processed row 619/2874
# Processed row 620/2874
# Processed row 621/2874
# Processed row 622/2874
# Processed row 623/2874
# Processed row 624/2874
# Processed row 625/2874
# Processed row 626/2874
# Processed row 627/2874
# Processed row 628/2874
# Processed row 629/2874
# Processed row 630/2874
# Processed row 631/2874
# Processed row 632/2874
# Processed row 633/2874
# Processed row 634/2874
# Processed row 635/2874
# Processed row 636/2874
# Processed row 637/2874
# Processed row 638/2874
# Processed row 639/2874
# Processed row 640/2874
# Processed row 641/2874
# Processed row 642/2874
# Processed row 643/2874
# Processed row 644/2874
# Processed row 645/2874
# Processed row 646/2874
# Processed row 647/2874
# Processed row 648/2874
# Processed row 649/2874
# Processed row 650/2874
# Processed row 651/2874
# Processed row 652/2874
# Processed row 653/2874
# Processed row 654/2874
# Processed row 655/2874
# Processed row 656/2874
# Processed row 657/2874
# Processed row 658/2874
# Processed row 659/2874
# Processed row 660/2874
# Processed row 661/2874
# Processed row 662/2874
# Processed row 663/2874
# Processed row 664/2874
# Processed row 665/2874
# Processed row 666/2874
# Processed row 667/2874
# Processed row 668/2874
# Processed row 669/2874
# Processed row 670/2874
# Processed row 671/2874
# Processed row 672/2874
# Processed row 673/2874
# Processed row 674/2874
# Processed row 675/2874
# Processed row 676/2874
# Processed row 677/2874
# Processed row 678/2874
# Processed row 679/2874
# Processed row 680/2874
# Processed row 681/2874
# Processed row 682/2874
# Processed row 683/2874
# Processed row 684/2874
# Processed row 685/2874
# Processed row 686/2874
# Processed row 687/2874
# Processed row 688/2874
# Processed row 689/2874
# Processed row 690/2874
# Processed row 691/2874
# Processed row 692/2874
# Processed row 693/2874
# Processed row 694/2874
# Processed row 695/2874
# Processed row 696/2874
# Processed row 697/2874
# Processed row 698/2874
# Processed row 699/2874
# Processed row 700/2874
# Processed row 701/2874
# Processed row 702/2874
# Processed row 703/2874
# Processed row 704/2874
# Processed row 705/2874
# Processed row 706/2874
# Processed row 707/2874
# Processed row 708/2874
# Processed row 709/2874
# Processed row 710/2874
# Processed row 711/2874
# Processed row 712/2874
# Processed row 713/2874
# Processed row 714/2874
# Processed row 715/2874
# Processed row 716/2874
# Processed row 717/2874
# Processed row 718/2874
# Processed row 719/2874
# Processed row 720/2874
# Processed row 721/2874
# Processed row 722/2874
# Processed row 723/2874
# Processed row 724/2874
# Processed row 725/2874
# Processed row 726/2874
# Processed row 727/2874
# Processed row 728/2874
# Processed row 729/2874
# Processed row 730/2874
# Processed row 731/2874
# Processed row 732/2874
# Processed row 733/2874
# Processed row 734/2874
# Processed row 735/2874
# Processed row 736/2874
# Processed row 737/2874
# Processed row 738/2874
# Processed row 739/2874
# Processed row 740/2874
# Processed row 741/2874
# Processed row 742/2874
# Processed row 743/2874
# Processed row 744/2874
# Processed row 745/2874
# Processed row 746/2874
# Processed row 747/2874
# Processed row 748/2874
# Processed row 749/2874
# Processed row 750/2874
# Processed row 751/2874
# Processed row 752/2874
# Processed row 753/2874
# Processed row 754/2874
# Processed row 755/2874
# Processed row 756/2874
# Processed row 757/2874
# Processed row 758/2874
# Processed row 759/2874
# Processed row 760/2874
# Processed row 761/2874
# Processed row 762/2874
# Processed row 763/2874
# Processed row 764/2874
# Processed row 765/2874
# Processed row 766/2874
# Processed row 767/2874
# Processed row 768/2874
# Processed row 769/2874
# Processed row 770/2874
# Processed row 771/2874
# Processed row 772/2874
# Processed row 773/2874
# Processed row 774/2874
# Processed row 775/2874
# Processed row 776/2874
# Processed row 777/2874
# Processed row 778/2874
# Processed row 779/2874
# Processed row 780/2874
# Processed row 781/2874
# Processed row 782/2874
# Processed row 783/2874
# Processed row 784/2874
# Processed row 785/2874
# Processed row 786/2874
# Processed row 787/2874
# Processed row 788/2874
# Processed row 789/2874
# Processed row 790/2874
# Processed row 791/2874
# Processed row 792/2874
# Processed row 793/2874
# Processed row 794/2874
# Processed row 795/2874
# Processed row 796/2874
# Processed row 797/2874
# Processed row 798/2874
# Processed row 799/2874
# Processed row 800/2874
# Processed row 801/2874
# Processed row 802/2874
# Processed row 803/2874
# Processed row 804/2874
# Processed row 805/2874
# Processed row 806/2874
# Processed row 807/2874
# Processed row 808/2874
# Processed row 809/2874
# Processed row 810/2874
# Processed row 811/2874
# Processed row 812/2874
# Processed row 813/2874
# Processed row 814/2874
# Processed row 815/2874
# Processed row 816/2874
# Processed row 817/2874
# Processed row 818/2874
# Processed row 819/2874
# Processed row 820/2874
# Processed row 821/2874
# Processed row 822/2874
# Processed row 823/2874
# Processed row 824/2874
# Processed row 825/2874
# Processed row 826/2874
# Processed row 827/2874
# Processed row 828/2874
# Processed row 829/2874
# Processed row 830/2874
# Processed row 831/2874
# Processed row 832/2874
# Processed row 833/2874
# Processed row 834/2874
# Processed row 835/2874
# Processed row 836/2874
# Processed row 837/2874
# Processed row 838/2874
# Processed row 839/2874
# Processed row 840/2874
# Processed row 841/2874
# Processed row 842/2874
# Processed row 843/2874
# Processed row 844/2874
# Processed row 845/2874
# Processed row 846/2874
# Processed row 847/2874
# Processed row 848/2874
# Processed row 849/2874
# Processed row 850/2874
# Processed row 851/2874
# Processed row 852/2874
# Processed row 853/2874
# Processed row 854/2874
# Processed row 855/2874
# Processed row 856/2874
# Processed row 857/2874
# Processed row 858/2874
# Processed row 859/2874
# Processed row 860/2874
# Processed row 861/2874
# Processed row 862/2874
# Processed row 863/2874
# Processed row 864/2874
# Processed row 865/2874
# Processed row 866/2874
# Processed row 867/2874
# Processed row 868/2874
# Processed row 869/2874
# Processed row 870/2874
# Processed row 871/2874
# Processed row 872/2874
# Processed row 873/2874
# Processed row 874/2874
# Processed row 875/2874
# Processed row 876/2874
# Processed row 877/2874
# Processed row 878/2874
# Processed row 879/2874
# Processed row 880/2874
# Processed row 881/2874
# Processed row 882/2874
# Processed row 883/2874
# Processed row 884/2874
# Processed row 885/2874
# Processed row 886/2874
# Processed row 887/2874
# Processed row 888/2874
# Processed row 889/2874
# Processed row 890/2874
# Processed row 891/2874
# Processed row 892/2874
# Processed row 893/2874
# Processed row 894/2874
# Processed row 895/2874
# Processed row 896/2874
# Processed row 897/2874
# Processed row 898/2874
# Processed row 899/2874
# Processed row 900/2874
# Processed row 901/2874
# Processed row 902/2874
# Processed row 903/2874
# Processed row 904/2874
# Processed row 905/2874
# Processed row 906/2874
# Processed row 907/2874
# Processed row 908/2874
# Processed row 909/2874
# Processed row 910/2874
# Processed row 911/2874
# Processed row 912/2874
# Processed row 913/2874
# Processed row 914/2874
# Processed row 915/2874
# Processed row 916/2874
# Processed row 917/2874
# Processed row 918/2874
# Processed row 919/2874
# Processed row 920/2874
# Processed row 921/2874
# Processed row 922/2874
# Processed row 923/2874
# Processed row 924/2874
# Processed row 925/2874
# Processed row 926/2874
# Processed row 927/2874
# Processed row 928/2874
# Processed row 929/2874
# Processed row 930/2874
# Processed row 931/2874
# Processed row 932/2874
# Processed row 933/2874
# Processed row 934/2874
# Processed row 935/2874
# Processed row 936/2874
# Processed row 937/2874
# Processed row 938/2874
# Processed row 939/2874
# Processed row 940/2874
# Processed row 941/2874
# Processed row 942/2874
# Processed row 943/2874
# Processed row 944/2874
# Processed row 945/2874
# Processed row 946/2874
# Processed row 947/2874
# Processed row 948/2874
# Processed row 949/2874
# Processed row 950/2874
# Processed row 951/2874
# Processed row 952/2874
# Processed row 953/2874
# Processed row 954/2874
# Processed row 955/2874
# Processed row 956/2874
# Processed row 957/2874
# Processed row 958/2874
# Processed row 959/2874
# Processed row 960/2874
# Processed row 961/2874
# Processed row 962/2874
# Processed row 963/2874
# Processed row 964/2874
# Processed row 965/2874
# Processed row 966/2874
# Processed row 967/2874
# Processed row 968/2874
# Processed row 969/2874
# Processed row 970/2874
# Processed row 971/2874
# Processed row 972/2874
# Processed row 973/2874
# Processed row 974/2874
# Processed row 975/2874
# Processed row 976/2874
# Processed row 977/2874
# Processed row 978/2874
# Processed row 979/2874
# Processed row 980/2874
# Processed row 981/2874
# Processed row 982/2874
# Processed row 983/2874
# Processed row 984/2874
# Processed row 985/2874
# Processed row 986/2874
# Processed row 987/2874
# Processed row 988/2874
# Processed row 989/2874
# Processed row 990/2874
# Processed row 991/2874
# Processed row 992/2874
# Processed row 993/2874
# Processed row 994/2874
# Processed row 995/2874
# Processed row 996/2874
# Processed row 997/2874
# Processed row 998/2874
# Processed row 999/2874
# Processed row 1000/2874
# Processed row 1001/2874
# Processed row 1002/2874
# Processed row 1003/2874
# Processed row 1004/2874
# Processed row 1005/2874
# Processed row 1006/2874
# Processed row 1007/2874
# Processed row 1008/2874
# Processed row 1009/2874
# Processed row 1010/2874
# Processed row 1011/2874
# Processed row 1012/2874
# Processed row 1013/2874
# Processed row 1014/2874
# Processed row 1015/2874
# Processed row 1016/2874
# Processed row 1017/2874
# Processed row 1018/2874
# Processed row 1019/2874
# Processed row 1020/2874
# Processed row 1021/2874
# Processed row 1022/2874
# Processed row 1023/2874
# Processed row 1024/2874
# Processed row 1025/2874
# Processed row 1026/2874
# Processed row 1027/2874
# Processed row 1028/2874
# Processed row 1029/2874
# Processed row 1030/2874
# Processed row 1031/2874
# Processed row 1032/2874
# Processed row 1033/2874
# Processed row 1034/2874
# Processed row 1035/2874
# Processed row 1036/2874
# Processed row 1037/2874
# Processed row 1038/2874
# Processed row 1039/2874
# Processed row 1040/2874
# Processed row 1041/2874
# Processed row 1042/2874
# Processed row 1043/2874
# Processed row 1044/2874
# Processed row 1045/2874
# Processed row 1046/2874
# Processed row 1047/2874
# Processed row 1048/2874
# Processed row 1049/2874
# Processed row 1050/2874
# Processed row 1051/2874
# Processed row 1052/2874
# Processed row 1053/2874
# Processed row 1054/2874
# Processed row 1055/2874
# Processed row 1056/2874
# Processed row 1057/2874
# Processed row 1058/2874
# Processed row 1059/2874
# Processed row 1060/2874
# Processed row 1061/2874
# Processed row 1062/2874
# Processed row 1063/2874
# Processed row 1064/2874
# Processed row 1065/2874
# Processed row 1066/2874
# Processed row 1067/2874
# Processed row 1068/2874
# Processed row 1069/2874
# Processed row 1070/2874
# Processed row 1071/2874
# Processed row 1072/2874
# Processed row 1073/2874
# Processed row 1074/2874
# Processed row 1075/2874
# Processed row 1076/2874
# Processed row 1077/2874
# Processed row 1078/2874
# Processed row 1079/2874
# Processed row 1080/2874
# Processed row 1081/2874
# Processed row 1082/2874
# Processed row 1083/2874
# Processed row 1084/2874
# Processed row 1085/2874
# Processed row 1086/2874
# Processed row 1087/2874
# Processed row 1088/2874
# Processed row 1089/2874
# Processed row 1090/2874
# Processed row 1091/2874
# Processed row 1092/2874
# Processed row 1093/2874
# Processed row 1094/2874
# Processed row 1095/2874
# Processed row 1096/2874
# Processed row 1097/2874
# Processed row 1098/2874
# Processed row 1099/2874
# Processed row 1100/2874
# Processed row 1101/2874
# Processed row 1102/2874
# Processed row 1103/2874
# Processed row 1104/2874
# Processed row 1105/2874
# Processed row 1106/2874
# Processed row 1107/2874
# Processed row 1108/2874
# Processed row 1109/2874
# Processed row 1110/2874
# Processed row 1111/2874
# Processed row 1112/2874
# Processed row 1113/2874
# Processed row 1114/2874
# Processed row 1115/2874
# Processed row 1116/2874
# Processed row 1117/2874
# Processed row 1118/2874
# Processed row 1119/2874
# Processed row 1120/2874
# Processed row 1121/2874
# Processed row 1122/2874
# Processed row 1123/2874
# Processed row 1124/2874
# Processed row 1125/2874
# Processed row 1126/2874
# Processed row 1127/2874
# Processed row 1128/2874
# Processed row 1129/2874
# Processed row 1130/2874
# Processed row 1131/2874
# Processed row 1132/2874
# Processed row 1133/2874
# Processed row 1134/2874
# Processed row 1135/2874
# Processed row 1136/2874
# Processed row 1137/2874
# Processed row 1138/2874
# Processed row 1139/2874
# Processed row 1140/2874
# Processed row 1141/2874
# Processed row 1142/2874
# Processed row 1143/2874
# Processed row 1144/2874
# Processed row 1145/2874
# Processed row 1146/2874
# Processed row 1147/2874
# Processed row 1148/2874
# Processed row 1149/2874
# Processed row 1150/2874
# Processed row 1151/2874
# Processed row 1152/2874
# Processed row 1153/2874
# Processed row 1154/2874
# Processed row 1155/2874
# Processed row 1156/2874
# Processed row 1157/2874
# Processed row 1158/2874
# Processed row 1159/2874
# Processed row 1160/2874
# Processed row 1161/2874
# Processed row 1162/2874
# Processed row 1163/2874
# Processed row 1164/2874
# Processed row 1165/2874
# Processed row 1166/2874
# Processed row 1167/2874
# Processed row 1168/2874
# Processed row 1169/2874
# Processed row 1170/2874
# Processed row 1171/2874
# Processed row 1172/2874
# Processed row 1173/2874
# Processed row 1174/2874
# Processed row 1175/2874
# Processed row 1176/2874
# Processed row 1177/2874
# Processed row 1178/2874
# Processed row 1179/2874
# Processed row 1180/2874
# Processed row 1181/2874
# Processed row 1182/2874
# Processed row 1183/2874
# Processed row 1184/2874
# Processed row 1185/2874
# Processed row 1186/2874
# Processed row 1187/2874
# Processed row 1188/2874
# Processed row 1189/2874
# Processed row 1190/2874
# Processed row 1191/2874
# Processed row 1192/2874
# Processed row 1193/2874
# Processed row 1194/2874
# Processed row 1195/2874
# Processed row 1196/2874
# Processed row 1197/2874
# Processed row 1198/2874
# Processed row 1199/2874
# Processed row 1200/2874
# Processed row 1201/2874
# Processed row 1202/2874
# Processed row 1203/2874
# Processed row 1204/2874
# Processed row 1205/2874
# Processed row 1206/2874
# Processed row 1207/2874
# Processed row 1208/2874
# Processed row 1209/2874
# Processed row 1210/2874
# Processed row 1211/2874
# Processed row 1212/2874
# Processed row 1213/2874
# Processed row 1214/2874
# Processed row 1215/2874
# Processed row 1216/2874
# Processed row 1217/2874
# Processed row 1218/2874
# Processed row 1219/2874
# Processed row 1220/2874
# Processed row 1221/2874
# Processed row 1222/2874
# Processed row 1223/2874
# Processed row 1224/2874
# Processed row 1225/2874
# Processed row 1226/2874
# Processed row 1227/2874
# Processed row 1228/2874
# Processed row 1229/2874
# Processed row 1230/2874
# Processed row 1231/2874
# Processed row 1232/2874
# Processed row 1233/2874
# Processed row 1234/2874
# Processed row 1235/2874
# Processed row 1236/2874
# Processed row 1237/2874
# Processed row 1238/2874
# Processed row 1239/2874
# Processed row 1240/2874
# Processed row 1241/2874
# Processed row 1242/2874
# Processed row 1243/2874
# Processed row 1244/2874
# Processed row 1245/2874
# Processed row 1246/2874
# Processed row 1247/2874
# Processed row 1248/2874
# Processed row 1249/2874
# Processed row 1250/2874
# Processed row 1251/2874
# Processed row 1252/2874
# Processed row 1253/2874
# Processed row 1254/2874
# Processed row 1255/2874
# Processed row 1256/2874
# Processed row 1257/2874
# Processed row 1258/2874
# Processed row 1259/2874
# Processed row 1260/2874
# Processed row 1261/2874
# Processed row 1262/2874
# Processed row 1263/2874
# Processed row 1264/2874
# Processed row 1265/2874
# Processed row 1266/2874
# Processed row 1267/2874
# Processed row 1268/2874
# Processed row 1269/2874
# Processed row 1270/2874
# Processed row 1271/2874
# Processed row 1272/2874
# Processed row 1273/2874
# Processed row 1274/2874
# Processed row 1275/2874
# Processed row 1276/2874
# Processed row 1277/2874
# Processed row 1278/2874
# Processed row 1279/2874
# Processed row 1280/2874
# Processed row 1281/2874
# Processed row 1282/2874
# Processed row 1283/2874
# Processed row 1284/2874
# Processed row 1285/2874
# Processed row 1286/2874
# Processed row 1287/2874
# Processed row 1288/2874
# Processed row 1289/2874
# Processed row 1290/2874
# Processed row 1291/2874
# Processed row 1292/2874
# Processed row 1293/2874
# Processed row 1294/2874
# Processed row 1295/2874
# Processed row 1296/2874
# Processed row 1297/2874
# Processed row 1298/2874
# Processed row 1299/2874
# Processed row 1300/2874
# Processed row 1301/2874
# Processed row 1302/2874
# Processed row 1303/2874
# Processed row 1304/2874
# Processed row 1305/2874
# Processed row 1306/2874
# Processed row 1307/2874
# Processed row 1308/2874
# Processed row 1309/2874
# Processed row 1310/2874
# Processed row 1311/2874
# Processed row 1312/2874
# Processed row 1313/2874
# Processed row 1314/2874
# Processed row 1315/2874
# Processed row 1316/2874
# Processed row 1317/2874
# Processed row 1318/2874
# Processed row 1319/2874
# Processed row 1320/2874
# Processed row 1321/2874
# Processed row 1322/2874
# Processed row 1323/2874
# Processed row 1324/2874
# Processed row 1325/2874
# Processed row 1326/2874
# Processed row 1327/2874
# Processed row 1328/2874
# Processed row 1329/2874
# Processed row 1330/2874
# Processed row 1331/2874
# Processed row 1332/2874
# Processed row 1333/2874
# Processed row 1334/2874
# Processed row 1335/2874
# Processed row 1336/2874
# Processed row 1337/2874
# Processed row 1338/2874
# Processed row 1339/2874
# Processed row 1340/2874
# Processed row 1341/2874
# Processed row 1342/2874
# Processed row 1343/2874
# Processed row 1344/2874
# Processed row 1345/2874
# Processed row 1346/2874
# Processed row 1347/2874
# Processed row 1348/2874
# Processed row 1349/2874
# Processed row 1350/2874
# Processed row 1351/2874
# Processed row 1352/2874
# Processed row 1353/2874
# Processed row 1354/2874
# Processed row 1355/2874
# Processed row 1356/2874
# Processed row 1357/2874
# Processed row 1358/2874
# Processed row 1359/2874
# Processed row 1360/2874
# Processed row 1361/2874
# Processed row 1362/2874
# Processed row 1363/2874
# Processed row 1364/2874
# Processed row 1365/2874
# Processed row 1366/2874
# Processed row 1367/2874
# Processed row 1368/2874
# Processed row 1369/2874
# Processed row 1370/2874
# Processed row 1371/2874
# Processed row 1372/2874
# Processed row 1373/2874
# Processed row 1374/2874
# Processed row 1375/2874
# Processed row 1376/2874
# Processed row 1377/2874
# Processed row 1378/2874
# Processed row 1379/2874
# Processed row 1380/2874
# Processed row 1381/2874
# Processed row 1382/2874
# Processed row 1383/2874
# Processed row 1384/2874
# Processed row 1385/2874
# Processed row 1386/2874
# Processed row 1387/2874
# Processed row 1388/2874
# Processed row 1389/2874
# Processed row 1390/2874
# Processed row 1391/2874
# Processed row 1392/2874
# Processed row 1393/2874
# Processed row 1394/2874
# Processed row 1395/2874
# Processed row 1396/2874
# Processed row 1397/2874
# Processed row 1398/2874
# Processed row 1399/2874
# Processed row 1400/2874
# Processed row 1401/2874
# Processed row 1402/2874
# Processed row 1403/2874
# Processed row 1404/2874
# Processed row 1405/2874
# Processed row 1406/2874
# Processed row 1407/2874
# Processed row 1408/2874
# Processed row 1409/2874
# Processed row 1410/2874
# Processed row 1411/2874
# Processed row 1412/2874
# Processed row 1413/2874
# Processed row 1414/2874
# Processed row 1415/2874
# Processed row 1416/2874
# Processed row 1417/2874
# Processed row 1418/2874
# Processed row 1419/2874
# Processed row 1420/2874
# Processed row 1421/2874
# Processed row 1422/2874
# Processed row 1423/2874
# Processed row 1424/2874
# Processed row 1425/2874
# Processed row 1426/2874
# Processed row 1427/2874
# Processed row 1428/2874
# Processed row 1429/2874
# Processed row 1430/2874
# Processed row 1431/2874
# Processed row 1432/2874
# Processed row 1433/2874
# Processed row 1434/2874
# Processed row 1435/2874
# Processed row 1436/2874
# Processed row 1437/2874
# Processed row 1438/2874
# Processed row 1439/2874
# Processed row 1440/2874
# Processed row 1441/2874
# Processed row 1442/2874
# Processed row 1443/2874
# Processed row 1444/2874
# Processed row 1445/2874
# Processed row 1446/2874
# Processed row 1447/2874
# Processed row 1448/2874
# Processed row 1449/2874
# Processed row 1450/2874
# Processed row 1451/2874
# Processed row 1452/2874
# Processed row 1453/2874
# Processed row 1454/2874
# Processed row 1455/2874
# Processed row 1456/2874
# Processed row 1457/2874
# Processed row 1458/2874
# Processed row 1459/2874
# Processed row 1460/2874
# Processed row 1461/2874
# Processed row 1462/2874
# Processed row 1463/2874
# Processed row 1464/2874
# Processed row 1465/2874
# Processed row 1466/2874
# Processed row 1467/2874
# Processed row 1468/2874
# Processed row 1469/2874
# Processed row 1470/2874
# Processed row 1471/2874
# Processed row 1472/2874
# Processed row 1473/2874
# Processed row 1474/2874
# Processed row 1475/2874
# Processed row 1476/2874
# Processed row 1477/2874
# Processed row 1478/2874
# Processed row 1479/2874
# Processed row 1480/2874
# Processed row 1481/2874
# Processed row 1482/2874
# Processed row 1483/2874
# Processed row 1484/2874
# Processed row 1485/2874
# Processed row 1486/2874
# Processed row 1487/2874
# Processed row 1488/2874
# Processed row 1489/2874
# Processed row 1490/2874
# Processed row 1491/2874
# Processed row 1492/2874
# Processed row 1493/2874
# Processed row 1494/2874
# Processed row 1495/2874
# Processed row 1496/2874
# Processed row 1497/2874
# Processed row 1498/2874
# Processed row 1499/2874
# Processed row 1500/2874
# Processed row 1501/2874
# Processed row 1502/2874
# Processed row 1503/2874
# Processed row 1504/2874
# Processed row 1505/2874
# Processed row 1506/2874
# Processed row 1507/2874
# Processed row 1508/2874
# Processed row 1509/2874
# Processed row 1510/2874
# Processed row 1511/2874
# Processed row 1512/2874
# Processed row 1513/2874
# Processed row 1514/2874
# Processed row 1515/2874
# Processed row 1516/2874
# Processed row 1517/2874
# Processed row 1518/2874
# Processed row 1519/2874
# Processed row 1520/2874
# Processed row 1521/2874
# Processed row 1522/2874
# Processed row 1523/2874
# Processed row 1524/2874
# Processed row 1525/2874
# Processed row 1526/2874
# Processed row 1527/2874
# Processed row 1528/2874
# Processed row 1529/2874
# Processed row 1530/2874
# Processed row 1531/2874
# Processed row 1532/2874
# Processed row 1533/2874
# Processed row 1534/2874
# Processed row 1535/2874
# Processed row 1536/2874
# Processed row 1537/2874
# Processed row 1538/2874
# Processed row 1539/2874
# Processed row 1540/2874
# Processed row 1541/2874
# Processed row 1542/2874
# Processed row 1543/2874
# Processed row 1544/2874
# Processed row 1545/2874
# Processed row 1546/2874
# Processed row 1547/2874
# Processed row 1548/2874
# Processed row 1549/2874
# Processed row 1550/2874
# Processed row 1551/2874
# Processed row 1552/2874
# Processed row 1553/2874
# Processed row 1554/2874
# Processed row 1555/2874
# Processed row 1556/2874
# Processed row 1557/2874
# Processed row 1558/2874
# Processed row 1559/2874
# Processed row 1560/2874
# Processed row 1561/2874
# Processed row 1562/2874
# Processed row 1563/2874
# Processed row 1564/2874
# Processed row 1565/2874
# Processed row 1566/2874
# Processed row 1567/2874
# Processed row 1568/2874
# Processed row 1569/2874
# Processed row 1570/2874
# Processed row 1571/2874
# Processed row 1572/2874
# Processed row 1573/2874
# Processed row 1574/2874
# Processed row 1575/2874
# Processed row 1576/2874
# Processed row 1577/2874
# Processed row 1578/2874
# Processed row 1579/2874
# Processed row 1580/2874
# Processed row 1581/2874
# Processed row 1582/2874
# Processed row 1583/2874
# Processed row 1584/2874
# Processed row 1585/2874
# Processed row 1586/2874
# Processed row 1587/2874
# Processed row 1588/2874
# Processed row 1589/2874
# Processed row 1590/2874
# Processed row 1591/2874
# Processed row 1592/2874
# Processed row 1593/2874
# Processed row 1594/2874
# Processed row 1595/2874
# Processed row 1596/2874
# Processed row 1597/2874
# Processed row 1598/2874
# Processed row 1599/2874
# Processed row 1600/2874
# Processed row 1601/2874
# Processed row 1602/2874
# Processed row 1603/2874
# Processed row 1604/2874
# Processed row 1605/2874
# Processed row 1606/2874
# Processed row 1607/2874
# Processed row 1608/2874
# Processed row 1609/2874
# Processed row 1610/2874
# Processed row 1611/2874
# Processed row 1612/2874
# Processed row 1613/2874
# Processed row 1614/2874
# Processed row 1615/2874
# Processed row 1616/2874
# Processed row 1617/2874
# Processed row 1618/2874
# Processed row 1619/2874
# Processed row 1620/2874
# Processed row 1621/2874
# Processed row 1622/2874
# Processed row 1623/2874
# Processed row 1624/2874
# Processed row 1625/2874
# Processed row 1626/2874
# Processed row 1627/2874
# Processed row 1628/2874
# Processed row 1629/2874
# Processed row 1630/2874
# Processed row 1631/2874
# Processed row 1632/2874
# Processed row 1633/2874
# Processed row 1634/2874
# Processed row 1635/2874
# Processed row 1636/2874
# Processed row 1637/2874
# Processed row 1638/2874
# Processed row 1639/2874
# Processed row 1640/2874
# Processed row 1641/2874
# Processed row 1642/2874
# Processed row 1643/2874
# Processed row 1644/2874
# Processed row 1645/2874
# Processed row 1646/2874
# Processed row 1647/2874
# Processed row 1648/2874
# Processed row 1649/2874
# Processed row 1650/2874
# Processed row 1651/2874
# Processed row 1652/2874
# Processed row 1653/2874
# Processed row 1654/2874
# Processed row 1655/2874
# Processed row 1656/2874
# Processed row 1657/2874
# Processed row 1658/2874
# Processed row 1659/2874
# Processed row 1660/2874
# Processed row 1661/2874
# Processed row 1662/2874
# Processed row 1663/2874
# Processed row 1664/2874
# Processed row 1665/2874
# Processed row 1666/2874
# Processed row 1667/2874
# Processed row 1668/2874
# Processed row 1669/2874
# Processed row 1670/2874
# Processed row 1671/2874
# Processed row 1672/2874
# Processed row 1673/2874
# Processed row 1674/2874
# Processed row 1675/2874
# Processed row 1676/2874
# Processed row 1677/2874
# Processed row 1678/2874
# Processed row 1679/2874
# Processed row 1680/2874
# Processed row 1681/2874
# Processed row 1682/2874
# Processed row 1683/2874
# Processed row 1684/2874
# Processed row 1685/2874
# Processed row 1686/2874
# Processed row 1687/2874
# Processed row 1688/2874
# Processed row 1689/2874
# Processed row 1690/2874
# Processed row 1691/2874
# Processed row 1692/2874
# Processed row 1693/2874
# Processed row 1694/2874
# Processed row 1695/2874
# Processed row 1696/2874
# Processed row 1697/2874
# Processed row 1698/2874
# Processed row 1699/2874
# Processed row 1700/2874
# Processed row 1701/2874
# Processed row 1702/2874
# Processed row 1703/2874
# Processed row 1704/2874
# Processed row 1705/2874
# Processed row 1706/2874
# Processed row 1707/2874
# Processed row 1708/2874
# Processed row 1709/2874
# Processed row 1710/2874
# Processed row 1711/2874
# Processed row 1712/2874
# Processed row 1713/2874
# Processed row 1714/2874
# Processed row 1715/2874
# Processed row 1716/2874
# Processed row 1717/2874
# Processed row 1718/2874
# Processed row 1719/2874
# Processed row 1720/2874
# Processed row 1721/2874
# Processed row 1722/2874
# Processed row 1723/2874
# Processed row 1724/2874
# Processed row 1725/2874
# Processed row 1726/2874
# Processed row 1727/2874
# Processed row 1728/2874
# Processed row 1729/2874
# Processed row 1730/2874
# Processed row 1731/2874
# Processed row 1732/2874
# Processed row 1733/2874
# Processed row 1734/2874
# Processed row 1735/2874
# Processed row 1736/2874
# Processed row 1737/2874
# Processed row 1738/2874
# Processed row 1739/2874
# Processed row 1740/2874
# Processed row 1741/2874
# Processed row 1742/2874
# Processed row 1743/2874
# Processed row 1744/2874
# Processed row 1745/2874
# Processed row 1746/2874
# Processed row 1747/2874
# Processed row 1748/2874
# Processed row 1749/2874
# Processed row 1750/2874
# Processed row 1751/2874
# Processed row 1752/2874
# Processed row 1753/2874
# Processed row 1754/2874
# Processed row 1755/2874
# Processed row 1756/2874
# Processed row 1757/2874
# Processed row 1758/2874
# Processed row 1759/2874
# Processed row 1760/2874
# Processed row 1761/2874
# Processed row 1762/2874
# Processed row 1763/2874
# Processed row 1764/2874
# Processed row 1765/2874
# Processed row 1766/2874
# Processed row 1767/2874
# Processed row 1768/2874
# Processed row 1769/2874
# Processed row 1770/2874
# Processed row 1771/2874
# Processed row 1772/2874
# Processed row 1773/2874
# Processed row 1774/2874
# Processed row 1775/2874
# Processed row 1776/2874
# Processed row 1777/2874
# Processed row 1778/2874
# Processed row 1779/2874
# Processed row 1780/2874
# Processed row 1781/2874
# Processed row 1782/2874
# Processed row 1783/2874
# Processed row 1784/2874
# Processed row 1785/2874
# Processed row 1786/2874
# Processed row 1787/2874
# Processed row 1788/2874
# Processed row 1789/2874
# Processed row 1790/2874
# Processed row 1791/2874
# Processed row 1792/2874
# Processed row 1793/2874
# Processed row 1794/2874
# Processed row 1795/2874
# Processed row 1796/2874
# Processed row 1797/2874
# Processed row 1798/2874
# Processed row 1799/2874
# Processed row 1800/2874
# Processed row 1801/2874
# Processed row 1802/2874
# Processed row 1803/2874
# Processed row 1804/2874
# Processed row 1805/2874
# Processed row 1806/2874
# Processed row 1807/2874
# Processed row 1808/2874
# Processed row 1809/2874
# Processed row 1810/2874
# Processed row 1811/2874
# Processed row 1812/2874
# Processed row 1813/2874
# Processed row 1814/2874
# Processed row 1815/2874
# Processed row 1816/2874
# Processed row 1817/2874
# Processed row 1818/2874
# Processed row 1819/2874
# Processed row 1820/2874
# Processed row 1821/2874
# Processed row 1822/2874
# Processed row 1823/2874
# Processed row 1824/2874
# Processed row 1825/2874
# Processed row 1826/2874
# Processed row 1827/2874
# Processed row 1828/2874
# Processed row 1829/2874
# Processed row 1830/2874
# Processed row 1831/2874
# Processed row 1832/2874
# Processed row 1833/2874
# Processed row 1834/2874
# Processed row 1835/2874
# Processed row 1836/2874
# Processed row 1837/2874
# Processed row 1838/2874
# Processed row 1839/2874
# Processed row 1840/2874
# Processed row 1841/2874
# Processed row 1842/2874
# Processed row 1843/2874
# Processed row 1844/2874
# Processed row 1845/2874
# Processed row 1846/2874
# Processed row 1847/2874
# Processed row 1848/2874
# Processed row 1849/2874
# Processed row 1850/2874
# Processed row 1851/2874
# Processed row 1852/2874
# Processed row 1853/2874
# Processed row 1854/2874
# Processed row 1855/2874
# Processed row 1856/2874
# Processed row 1857/2874
# Processed row 1858/2874
# Processed row 1859/2874
# Processed row 1860/2874
# Processed row 1861/2874
# Processed row 1862/2874
# Processed row 1863/2874
# Processed row 1864/2874
# Processed row 1865/2874
# Processed row 1866/2874
# Processed row 1867/2874
# Processed row 1868/2874
# Processed row 1869/2874
# Processed row 1870/2874
# Processed row 1871/2874
# Processed row 1872/2874
# Processed row 1873/2874
# Processed row 1874/2874
# Processed row 1875/2874
# Processed row 1876/2874
# Processed row 1877/2874
# Processed row 1878/2874
# Processed row 1879/2874
# Processed row 1880/2874
# Processed row 1881/2874
# Processed row 1882/2874
# Processed row 1883/2874
# Processed row 1884/2874
# Processed row 1885/2874
# Processed row 1886/2874
# Processed row 1887/2874
# Processed row 1888/2874
# Processed row 1889/2874
# Processed row 1890/2874
# Processed row 1891/2874
# Processed row 1892/2874
# Processed row 1893/2874
# Processed row 1894/2874
# Processed row 1895/2874
# Processed row 1896/2874
# Processed row 1897/2874
# Processed row 1898/2874
# Processed row 1899/2874
# Processed row 1900/2874
# Processed row 1901/2874
# Processed row 1902/2874
# Processed row 1903/2874
# Processed row 1904/2874
# Processed row 1905/2874
# Processed row 1906/2874
# Processed row 1907/2874
# Processed row 1908/2874
# Processed row 1909/2874
# Processed row 1910/2874
# Processed row 1911/2874
# Processed row 1912/2874
# Processed row 1913/2874
# Processed row 1914/2874
# Processed row 1915/2874
# Processed row 1916/2874
# Processed row 1917/2874
# Processed row 1918/2874
# Processed row 1919/2874
# Processed row 1920/2874
# Processed row 1921/2874
# Processed row 1922/2874
# Processed row 1923/2874
# Processed row 1924/2874
# Processed row 1925/2874
# Processed row 1926/2874
# Processed row 1927/2874
# Processed row 1928/2874
# Processed row 1929/2874
# Processed row 1930/2874
# Processed row 1931/2874
# Processed row 1932/2874
# Processed row 1933/2874
# Processed row 1934/2874
# Processed row 1935/2874
# Processed row 1936/2874
# Processed row 1937/2874
# Processed row 1938/2874
# Processed row 1939/2874
# Processed row 1940/2874
# Processed row 1941/2874
# Processed row 1942/2874
# Processed row 1943/2874
# Processed row 1944/2874
# Processed row 1945/2874
# Processed row 1946/2874
# Processed row 1947/2874
# Processed row 1948/2874
# Processed row 1949/2874
# Processed row 1950/2874
# Processed row 1951/2874
# Processed row 1952/2874
# Processed row 1953/2874
# Processed row 1954/2874
# Processed row 1955/2874
# Processed row 1956/2874
# Processed row 1957/2874
# Processed row 1958/2874
# Processed row 1959/2874
# Processed row 1960/2874
# Processed row 1961/2874
# Processed row 1962/2874
# Processed row 1963/2874
# Processed row 1964/2874
# Processed row 1965/2874
# Processed row 1966/2874
# Processed row 1967/2874
# Processed row 1968/2874
# Processed row 1969/2874
# Processed row 1970/2874
# Processed row 1971/2874
# Processed row 1972/2874
# Processed row 1973/2874
# Processed row 1974/2874
# Processed row 1975/2874
# Processed row 1976/2874
# Processed row 1977/2874
# Processed row 1978/2874
# Processed row 1979/2874
# Processed row 1980/2874
# Processed row 1981/2874
# Processed row 1982/2874
# Processed row 1983/2874
# Processed row 1984/2874
# Processed row 1985/2874
# Processed row 1986/2874
# Processed row 1987/2874
# Processed row 1988/2874
# Processed row 1989/2874
# Processed row 1990/2874
# Processed row 1991/2874
# Processed row 1992/2874
# Processed row 1993/2874
# Processed row 1994/2874
# Processed row 1995/2874
# Processed row 1996/2874
# Processed row 1997/2874
# Processed row 1998/2874
# Processed row 1999/2874
# Processed row 2000/2874
# Processed row 2001/2874
# Processed row 2002/2874
# Processed row 2003/2874
# Processed row 2004/2874
# Processed row 2005/2874
# Processed row 2006/2874
# Processed row 2007/2874
# Processed row 2008/2874
# Processed row 2009/2874
# Processed row 2010/2874
# Processed row 2011/2874
# Processed row 2012/2874
# Processed row 2013/2874
# Processed row 2014/2874
# Processed row 2015/2874
# Processed row 2016/2874
# Processed row 2017/2874
# Processed row 2018/2874
# Processed row 2019/2874
# Processed row 2020/2874
# Processed row 2021/2874
# Processed row 2022/2874
# Processed row 2023/2874
# Processed row 2024/2874
# Processed row 2025/2874
# Processed row 2026/2874
# Processed row 2027/2874
# Processed row 2028/2874
# Processed row 2029/2874
# Processed row 2030/2874
# Processed row 2031/2874
# Processed row 2032/2874
# Processed row 2033/2874
# Processed row 2034/2874
# Processed row 2035/2874
# Processed row 2036/2874
# Processed row 2037/2874
# Processed row 2038/2874
# Processed row 2039/2874
# Processed row 2040/2874
# Processed row 2041/2874
# Processed row 2042/2874
# Processed row 2043/2874
# Processed row 2044/2874
# Processed row 2045/2874
# Processed row 2046/2874
# ...
# Processed row 2209/2874
# Processed row 2210/2874
# Processed row 2211/2874
# Processed row 2212/2874
# Processed row 2213/2874
# Processed row 2214/2874
# Processed row 2215/2874
# Processed row 2216/2874
# Processed row 2217/2874
# Processed row 2218/2874
# Processed row 2219/2874
# Processed row 2220/2874
# Processed row 2221/2874
# Processed row 2222/2874
# Processed row 2223/2874
# Processed row 2224/2874
# Processed row 2225/2874
# Processed row 2226/2874
# Processed row 2227/2874
# Processed row 2228/2874
# Processed row 2229/2874
# Processed row 2230/2874
# Processed row 2231/2874
# Processed row 2232/2874
# Processed row 2233/2874
# Processed row 2234/2874
# Processed row 2235/2874
# Processed row 2236/2874
# Processed row 2237/2874
# Processed row 2238/2874
# Processed row 2239/2874
# Processed row 2240/2874
# Processed row 2241/2874
# Processed row 2242/2874
# Processed row 2243/2874
# Processed row 2244/2874
# Processed row 2245/2874
# Processed row 2246/2874
# Processed row 2247/2874
# Processed row 2248/2874
# Processed row 2249/2874
# Processed row 2250/2874
# Processed row 2251/2874
# Processed row 2252/2874
# Processed row 2253/2874
# Processed row 2254/2874
# Processed row 2255/2874
# Processed row 2256/2874
# Processed row 2257/2874
# Processed row 2258/2874
# Processed row 2259/2874
# Processed row 2260/2874
# Processed row 2261/2874
# Processed row 2262/2874
# Processed row 2263/2874
# Processed row 2264/2874
# Processed row 2265/2874
# Processed row 2266/2874
# Processed row 2267/2874
# Processed row 2268/2874
# Processed row 2269/2874
# Processed row 2270/2874
# Processed row 2271/2874
# Processed row 2272/2874
# Processed row 2273/2874
# Processed row 2274/2874
# Processed row 2275/2874
# Processed row 2276/2874
# Processed row 2277/2874
# Processed row 2278/2874
# Processed row 2279/2874
# Processed row 2280/2874
# Processed row 2281/2874
# Processed row 2282/2874
# Processed row 2283/2874
# Processed row 2284/2874
# Processed row 2285/2874
# Processed row 2286/2874
# Processed row 2287/2874
# Processed row 2288/2874
# Processed row 2289/2874
# Processed row 2290/2874
# Processed row 2291/2874
# Processed row 2292/2874
# Processed row 2293/2874
# Processed row 2294/2874
# Processed row 2295/2874
# Processed row 2296/2874
# Processed row 2297/2874
# Processed row 2298/2874
# Processed row 2299/2874
# Processed row 2300/2874
# Processed row 2301/2874
# Processed row 2302/2874
# Processed row 2303/2874
# Processed row 2304/2874
# Processed row 2305/2874
# Processed row 2306/2874
# Processed row 2307/2874
# Processed row 2308/2874
# Processed row 2309/2874
# Processed row 2310/2874
# Processed row 2311/2874
# Processed row 2312/2874
# Processed row 2313/2874
# Processed row 2314/2874
# Processed row 2315/2874
# Processed row 2316/2874
# Processed row 2317/2874
# Processed row 2318/2874
# Processed row 2319/2874
# Processed row 2320/2874
# Processed row 2321/2874
# Processed row 2322/2874
# Processed row 2323/2874
# Processed row 2324/2874
# Processed row 2325/2874
# Processed row 2326/2874
# Processed row 2327/2874
# Processed row 2328/2874
# Processed row 2329/2874
# Processed row 2330/2874
# Processed row 2331/2874
# Processed row 2332/2874
# Processed row 2333/2874
# Processed row 2334/2874
# Processed row 2335/2874
# Processed row 2336/2874
# Processed row 2337/2874
# Processed row 2338/2874
# Processed row 2339/2874
# Processed row 2340/2874
# Processed row 2341/2874
# Processed row 2342/2874
# Processed row 2343/2874
# Processed row 2344/2874
# Processed row 2345/2874
# Processed row 2346/2874
# Processed row 2347/2874
# Processed row 2348/2874
# Processed row 2349/2874
# Processed row 2350/2874
# Processed row 2351/2874
# Processed row 2352/2874
# Processed row 2353/2874
# Processed row 2354/2874
# Processed row 2355/2874
# Processed row 2356/2874
# Processed row 2357/2874
# Processed row 2358/2874
# Processed row 2359/2874
# Processed row 2360/2874
# Processed row 2361/2874
# Processed row 2362/2874
# Processed row 2363/2874
# Processed row 2364/2874
# Processed row 2365/2874
# Processed row 2366/2874
# Processed row 2367/2874
# Processed row 2368/2874
# Processed row 2369/2874
# Processed row 2370/2874
# Processed row 2371/2874
# Processed row 2372/2874
# Processed row 2373/2874
# Processed row 2374/2874
# Processed row 2375/2874
# Processed row 2376/2874
# Processed row 2377/2874
# Processed row 2378/2874
# Processed row 2379/2874
# Processed row 2380/2874
# Processed row 2381/2874
# Processed row 2382/2874
# Processed row 2383/2874
# Processed row 2384/2874
# Processed row 2385/2874
# Processed row 2386/2874
# Processed row 2387/2874
# Processed row 2388/2874
# Processed row 2389/2874
# Processed row 2390/2874
# Processed row 2391/2874
# Processed row 2392/2874
# Processed row 2393/2874
# Processed row 2394/2874
# Processed row 2395/2874
# Processed row 2396/2874
# Processed row 2397/2874
# Processed row 2398/2874
# Processed row 2399/2874
# Processed row 2400/2874
# Processed row 2401/2874
# Processed row 2402/2874
# Processed row 2403/2874
# Processed row 2404/2874
# Processed row 2405/2874
# Processed row 2406/2874
# Processed row 2407/2874
# Processed row 2408/2874
# Processed row 2409/2874
# Processed row 2410/2874
# Processed row 2411/2874
# Processed row 2412/2874
# Processed row 2413/2874
# Processed row 2414/2874
# Processed row 2415/2874
# Processed row 2416/2874
# Processed row 2417/2874
# Processed row 2418/2874
# Processed row 2419/2874
# Processed row 2420/2874
# Processed row 2421/2874
# Processed row 2422/2874
# Processed row 2423/2874
# Processed row 2424/2874
# Processed row 2425/2874
# Processed row 2426/2874
# Processed row 2427/2874
# Processed row 2428/2874
# Processed row 2429/2874
# Processed row 2430/2874
# Processed row 2431/2874
# Processed row 2432/2874
# Processed row 2433/2874
# Processed row 2434/2874
# Processed row 2435/2874
# Processed row 2436/2874
# Processed row 2437/2874
# Processed row 2438/2874
# Processed row 2439/2874
# Processed row 2440/2874
# Processed row 2441/2874
# Processed row 2442/2874
# Processed row 2443/2874
# Processed row 2444/2874
# Processed row 2445/2874
# Processed row 2446/2874
# Processed row 2447/2874
# Processed row 2448/2874
# Processed row 2449/2874
# Processed row 2450/2874
# Processed row 2451/2874
# Processed row 2452/2874
# Processed row 2453/2874
# Processed row 2454/2874
# Processed row 2455/2874
# Processed row 2456/2874
# Processed row 2457/2874
# Processed row 2458/2874
# Processed row 2459/2874
# Processed row 2460/2874
# Processed row 2461/2874
# Processed row 2462/2874
# Processed row 2463/2874
# Processed row 2464/2874
# Processed row 2465/2874
# Processed row 2466/2874
# Processed row 2467/2874
# Processed row 2468/2874
# Processed row 2469/2874
# Processed row 2470/2874
# Processed row 2471/2874
# Processed row 2472/2874
# Processed row 2473/2874
# Processed row 2474/2874
# Processed row 2475/2874
# Processed row 2476/2874
# Processed row 2477/2874
# Processed row 2478/2874
# Processed row 2479/2874
# Processed row 2480/2874
# Processed row 2481/2874
# Processed row 2482/2874
# Processed row 2483/2874
# Processed row 2484/2874
# Processed row 2485/2874
# Processed row 2486/2874
# Processed row 2487/2874
# Processed row 2488/2874
# Processed row 2489/2874
# Processed row 2490/2874
# Processed row 2491/2874
# Processed row 2492/2874
# Processed row 2493/2874
# Processed row 2494/2874
# Processed row 2495/2874
# Processed row 2496/2874
# Processed row 2497/2874
# Processed row 2498/2874
# Processed row 2499/2874
# Processed row 2500/2874
# Processed row 2501/2874
# Processed row 2502/2874
# Processed row 2503/2874
# Processed row 2504/2874
# Processed row 2505/2874
# Processed row 2506/2874
# Processed row 2507/2874
# Processed row 2508/2874
# Processed row 2509/2874
# Processed row 2510/2874
# Processed row 2511/2874
# Processed row 2512/2874
# Processed row 2513/2874
# Processed row 2514/2874
# Processed row 2515/2874
# Processed row 2516/2874
# Processed row 2517/2874
# Processed row 2518/2874
# Processed row 2519/2874
# Processed row 2520/2874
# Processed row 2521/2874
# Processed row 2522/2874
# Processed row 2523/2874
# Processed row 2524/2874
# Processed row 2525/2874
# Processed row 2526/2874
# Processed row 2527/2874
# Processed row 2528/2874
# Processed row 2529/2874
# Processed row 2530/2874
# Processed row 2531/2874
# Processed row 2532/2874
# Processed row 2533/2874
# Processed row 2534/2874
# Processed row 2535/2874
# Processed row 2536/2874
# Processed row 2537/2874
# Processed row 2538/2874
# Processed row 2539/2874
# Processed row 2540/2874
# Processed row 2541/2874
# Processed row 2542/2874
# Processed row 2543/2874
# Processed row 2544/2874
# Processed row 2545/2874
# Processed row 2546/2874
# Processed row 2547/2874
# Processed row 2548/2874
# Processed row 2549/2874
# Processed row 2550/2874
# Processed row 2551/2874
# Processed row 2552/2874
# Processed row 2553/2874
# Processed row 2554/2874
# Processed row 2555/2874
# Processed row 2556/2874
# Processed row 2557/2874
# Processed row 2558/2874
# Processed row 2559/2874
# Processed row 2560/2874
# Processed row 2561/2874
# Processed row 2562/2874
# Processed row 2563/2874
# Processed row 2564/2874
# Processed row 2565/2874
# Processed row 2566/2874
# Processed row 2567/2874
# Processed row 2568/2874
# Processed row 2569/2874
# Processed row 2570/2874
# Processed row 2571/2874
# Processed row 2572/2874
# Processed row 2573/2874
# Processed row 2574/2874
# Processed row 2575/2874
# Processed row 2576/2874
# Processed row 2577/2874
# Processed row 2578/2874
# Processed row 2579/2874
# Processed row 2580/2874
# Processed row 2581/2874
# Processed row 2582/2874
# Processed row 2583/2874
# Processed row 2584/2874
# Processed row 2585/2874
# Processed row 2586/2874
# Processed row 2587/2874
# Processed row 2588/2874
# Processed row 2589/2874
# Processed row 2590/2874
# Processed row 2591/2874
# Processed row 2592/2874
# Processed row 2593/2874
# Processed row 2594/2874
# Processed row 2595/2874
# Processed row 2596/2874
# Processed row 2597/2874
# Processed row 2598/2874
# Processed row 2599/2874
# Processed row 2600/2874
# Processed row 2601/2874
# Processed row 2602/2874
# Processed row 2603/2874
# Processed row 2604/2874
# Processed row 2605/2874
# Processed row 2606/2874
# Processed row 2607/2874
# Processed row 2608/2874
# Processed row 2609/2874
# Processed row 2610/2874
# Processed row 2611/2874
# Processed row 2612/2874
# Processed row 2613/2874
# Processed row 2614/2874
# Processed row 2615/2874
# Processed row 2616/2874
# Processed row 2617/2874
# Processed row 2618/2874
# Processed row 2619/2874
# Processed row 2620/2874
# Processed row 2621/2874
# Processed row 2622/2874
# Processed row 2623/2874
# Processed row 2624/2874
# Processed row 2625/2874
# Processed row 2626/2874
# Processed row 2627/2874
# Processed row 2628/2874
# Processed row 2629/2874
# Processed row 2630/2874
# Processed row 2631/2874
# Processed row 2632/2874
# Processed row 2633/2874
# Processed row 2634/2874
# Processed row 2635/2874
# Processed row 2636/2874
# Processed row 2637/2874
# Processed row 2638/2874
# Processed row 2639/2874
# Processed row 2640/2874
# Processed row 2641/2874
# Processed row 2642/2874
# Processed row 2643/2874
# Processed row 2644/2874
# Processed row 2645/2874
# Processed row 2646/2874
# Processed row 2647/2874
# Processed row 2648/2874
# Processed row 2649/2874
# Processed row 2650/2874
# Processed row 2651/2874
# Processed row 2652/2874
# Processed row 2653/2874
# Processed row 2654/2874
# Processed row 2655/2874
# Processed row 2656/2874
# Processed row 2657/2874
# Processed row 2658/2874
# Processed row 2659/2874
# Processed row 2660/2874
# Processed row 2661/2874
# Processed row 2662/2874
# Processed row 2663/2874
# Processed row 2664/2874
# Processed row 2665/2874
# Processed row 2666/2874
# Processed row 2667/2874
# Processed row 2668/2874
# Processed row 2669/2874
# Processed row 2670/2874
# Processed row 2671/2874
# Processed row 2672/2874
# Processed row 2673/2874
# Processed row 2674/2874
# Processed row 2675/2874
# Processed row 2676/2874
# Processed row 2677/2874
# Processed row 2678/2874
# Processed row 2679/2874
# Processed row 2680/2874
# Processed row 2681/2874
# Processed row 2682/2874
# Processed row 2683/2874
# Processed row 2684/2874
# Processed row 2685/2874
# Processed row 2686/2874
# Processed row 2687/2874
# Processed row 2688/2874
# Processed row 2689/2874
# Processed row 2690/2874
# Processed row 2691/2874
# Processed row 2692/2874
# Processed row 2693/2874
# Processed row 2694/2874
# Processed row 2695/2874
# Processed row 2696/2874
# Processed row 2697/2874
# Processed row 2698/2874
# Processed row 2699/2874
# Processed row 2700/2874
# Processed row 2701/2874
# Processed row 2702/2874
# Processed row 2703/2874
# Processed row 2704/2874
# Processed row 2705/2874
# Processed row 2706/2874
# Processed row 2707/2874
# Processed row 2708/2874
# Processed row 2709/2874
# Processed row 2710/2874
# Processed row 2711/2874
# Processed row 2712/2874
# Processed row 2713/2874
# Processed row 2714/2874
# Processed row 2715/2874
# Processed row 2716/2874
# Processed row 2717/2874
# Processed row 2718/2874
# Processed row 2719/2874
# Processed row 2720/2874
# Processed row 2721/2874
# Processed row 2722/2874
# Processed row 2723/2874
# Processed row 2724/2874
# Processed row 2725/2874
# Processed row 2726/2874
# Processed row 2727/2874
# Processed row 2728/2874
# Processed row 2729/2874
# Processed row 2730/2874
# Processed row 2731/2874
# Processed row 2732/2874
# Processed row 2733/2874
# Processed row 2734/2874
# Processed row 2735/2874
# Processed row 2736/2874
# Processed row 2737/2874
# Processed row 2738/2874
# Processed row 2739/2874
# Processed row 2740/2874
# Processed row 2741/2874
# Processed row 2742/2874
# Processed row 2743/2874
# Processed row 2744/2874
# Processed row 2745/2874
# Processed row 2746/2874
# Processed row 2747/2874
# Processed row 2748/2874
# Processed row 2749/2874
# Processed row 2750/2874
# Processed row 2751/2874
# Processed row 2752/2874
# Processed row 2753/2874
# Processed row 2754/2874
# Processed row 2755/2874
# Processed row 2756/2874
# Processed row 2757/2874
# Processed row 2758/2874
# Processed row 2759/2874
# Processed row 2760/2874
# Processed row 2761/2874
# Processed row 2762/2874
# Processed row 2763/2874
# Processed row 2764/2874
# Processed row 2765/2874
# Processed row 2766/2874
# Processed row 2767/2874
# Processed row 2768/2874
# Processed row 2769/2874
# Processed row 2770/2874
# Processed row 2771/2874
# Processed row 2772/2874
# Processed row 2773/2874
# Processed row 2774/2874
# Processed row 2775/2874
# Processed row 2776/2874
# Processed row 2777/2874
# Processed row 2778/2874
# Processed row 2779/2874
# Processed row 2780/2874
# Processed row 2781/2874
# Processed row 2782/2874
# Processed row 2783/2874
# Processed row 2784/2874
# Processed row 2785/2874
# Processed row 2786/2874
# Processed row 2787/2874
# Processed row 2788/2874
# Processed row 2789/2874
# Processed row 2790/2874
# Processed row 2791/2874
# Processed row 2792/2874
# Processed row 2793/2874
# Processed row 2794/2874
# Processed row 2795/2874
# Processed row 2796/2874
# Processed row 2797/2874
# Processed row 2798/2874
# Processed row 2799/2874
# Processed row 2800/2874
# Processed row 2801/2874
# Processed row 2802/2874
# Processed row 2803/2874
# Processed row 2804/2874
# Processed row 2805/2874
# Processed row 2806/2874
# Processed row 2807/2874
# Processed row 2808/2874
# Processed row 2809/2874
# Processed row 2810/2874
# Processed row 2811/2874
# Processed row 2812/2874
# Processed row 2813/2874
# Processed row 2814/2874
# Processed row 2815/2874
# Processed row 2816/2874
# Processed row 2817/2874
# Processed row 2818/2874
# Processed row 2819/2874
# Processed row 2820/2874
# Processed row 2821/2874
# Processed row 2822/2874
# Processed row 2823/2874
# Processed row 2824/2874
# Processed row 2825/2874
# Processed row 2826/2874
# Processed row 2827/2874
# Processed row 2828/2874
# Processed row 2829/2874
# Processed row 2830/2874
# Processed row 2831/2874
# Processed row 2832/2874
# Processed row 2833/2874
# Processed row 2834/2874
# Processed row 2835/2874
# Processed row 2836/2874
# Processed row 2837/2874
# Processed row 2838/2874
# Processed row 2839/2874
# Processed row 2840/2874
# Processed row 2841/2874
# Processed row 2842/2874
# Processed row 2843/2874
# Processed row 2844/2874
# Processed row 2845/2874
# Processed row 2846/2874
# Processed row 2847/2874
# Processed row 2848/2874
# Processed row 2849/2874
# Processed row 2850/2874
# Processed row 2851/2874
# Processed row 2852/2874
# Processed row 2853/2874
# Processed row 2854/2874
# Processed row 2855/2874
# Processed row 2856/2874
# Processed row 2857/2874
# Processed row 2858/2874
# Processed row 2859/2874
# Processed row 2860/2874
# Processed row 2861/2874
# Processed row 2862/2874
# Processed row 2863/2874
# Processed row 2864/2874
# Processed row 2865/2874
# Processed row 2866/2874
# Processed row 2867/2874
# Processed row 2868/2874
# Processed row 2869/2874
# Processed row 2870/2874
# Processed row 2871/2874
# Processed row 2872/2874
# Processed row 2873/2874
# Processed row 2874/2874

# %%
df
# Out:
#             Date       long        lat  Drainage_density  Slope_tif2  \
# 0     12-01-2023 -16.670616  13.488346         13.499496    0.000000
# 1     12-01-2023 -16.665998  13.488376         14.573664    0.000000
# 2     12-01-2023 -16.684438  13.483734         15.609715    0.000000
# 3     12-01-2023 -16.679820  13.483765         13.571120    0.000000
# 4     12-01-2023 -16.675202  13.483796         13.922873    0.000000
# ...          ...        ...        ...               ...         ...
# 2869  12-01-2023 -16.746177  13.076569         34.977886    1.642019
# 2870  12-01-2023 -16.741567  13.076600         44.632805    2.321531
# 2871  12-01-2023 -16.736957  13.076631         49.922588    2.706814
# 2872  12-01-2023 -16.732347  13.076662         49.457001    0.734494
# 2873  12-01-2023 -16.727737  13.076693         48.282181    0.929039
#
#       Hydrogeo  Curvatu_tif2  NASADEM_HGT DepthToGroundwater  NASA_IMERG_Late  \
# 0          5.0 -0.000000e+00          0.0                0-7              0.0
# 1          5.0 -0.000000e+00          0.0                0-7              0.0
# 2          5.0 -0.000000e+00          0.0                0-7              0.0
# 3          5.0 -0.000000e+00          0.0                0-7              0.0
# 4          5.0 -0.000000e+00          0.0                0-7              0.0
# ...        ...           ...          ...                ...              ...
# 2869       5.0  2.592000e+09          9.0                0-7              0.0
# 2870       5.0 -5.184000e+09          2.0                0-7              0.0
# 2871       5.0  3.888000e+09          2.0                0-7              0.0
# 2872       5.0 -3.888000e+09          3.0                0-7              0.0
# 2873       5.0 -1.296000e+09          4.0                0-7              0.0
#
#         LIS_ET  LIS_Soil_Moisture_Combined  LIS_Streamflow
# 0     1.766242                    0.209369        0.179610
# 1     1.766242                    0.209369        0.179610
# 2     1.252523                    0.220998        0.170694
# 3     1.766242                    0.209369        0.179610
# 4     1.766242                    0.209369        0.179610
# ...        ...                         ...             ...
# 2869  2.358303                    0.295715        0.001112
# 2870  2.358303                    0.295715        0.001112
# 2871  2.000822                    0.274988        0.106376
# 2872  2.000822                    0.274988        0.106376
# 2873  2.000822                    0.274988        0.106376
#
# [2874 rows x 13 columns]

# %%
# Save the DataFrame to a CSV file
df.to_csv("../../data/final_dataset/processed_data/merged_data.csv", index=False)

# %%
nan_counts = df.isna().sum()
print("NaN Counts in each column:\n", nan_counts)
# Out:
# NaN Counts in each column:
#  Date                          0
# long                          0
# lat                           0
# Drainage_density              0
# Slope_tif2                    0
# Hydrogeo                      0
# Curvatu_tif2                  0
# NASADEM_HGT                   0
# DepthToGroundwater            0
# NASA_IMERG_Late               0
# LIS_ET                        0
# LIS_Soil_Moisture_Combined    0
# LIS_Streamflow                0
# dtype: int64
