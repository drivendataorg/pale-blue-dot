# %% [markdown]
# # This file process a a folder with all the .csv files taked from AppEARS with data from MOD13Q1 (NDVI), pre-process them and save them.

# %% [markdown]
# ### First we make explicit the installation of libraries we will use and the importing.

# %%
# !pip3 install -q --upgrade pip
# !pip3 install -q pandas numpy matplotlib seaborn openpyxl climateserv requests netCDF4 xarray pyproj

# %%
import sys
from pathlib import Path

# Calculate the path to the scripts folder relative to the current notebook.
scripts_dir = Path("../../").resolve()

# Add the scripts directory to the sys.path if it's not already there.
if str(scripts_dir) not in sys.path:
    sys.path.append(str(scripts_dir))

import pandas as pd
from scripts.preprocessing.appears_ndvi_pre_process import clean_and_save_ndvi_dataset, process_all_csv_in_directory, merge_additional_data

# %% [markdown]
# ### We use the function declareds in the python file in this directory: 'scripts/preprocessing/appears_ndvi_pre_process.py'

# %% [markdown]
# ### Here below we use the function process_all_csv_in_directory to clean the data, basically we the data that has clouds. The value 0b00000000000000000000000000000000 it means data without clouds.

# %%
directory_path = '../../data/original_data/appears/ndvi/'
output_directory = '../../data/processed_data/appears/ndvi'
process_all_csv_in_directory(directory_path=directory_path, output_directory=output_directory)
# Out:
# Processing file: ../../data/original_data/appears/ndvi/0000024001.csv
# Percentage of rows with value '0b00000000000000000000000000000000': 70.81%
# Number of rows after cleaning: 131
# Data cleaning complete. Number of rows after cleaning and filling: 2923
# Finished processing: ../../data/original_data/appears/ndvi/0000024001.csv
# Processing file: ../../data/original_data/appears/ndvi/NWP00001.csv
# Percentage of rows with value '0b00000000000000000000000000000000': 68.65%
# Number of rows after cleaning: 127
# Data cleaning complete. Number of rows after cleaning and filling: 2923
# Finished processing: ../../data/original_data/appears/ndvi/NWP00001.csv
# Processing file: ../../data/original_data/appears/ndvi/0000000001.csv
# Percentage of rows with value '0b00000000000000000000000000000000': 68.65%
# Number of rows after cleaning: 127
# Data cleaning complete. Number of rows after cleaning and filling: 2923
# Finished processing: ../../data/original_data/appears/ndvi/0000000001.csv
# Processing file: ../../data/original_data/appears/ndvi/NWP24001.csv
# Percentage of rows with value '0b00000000000000000000000000000000': 70.81%
# Number of rows after cleaning: 131
# Data cleaning complete. Number of rows after cleaning and filling: 2923
# Finished processing: ../../data/original_data/appears/ndvi/NWP24001.csv
# Processing file: ../../data/original_data/appears/ndvi/NWP61001.csv
# Percentage of rows with value '0b00000000000000000000000000000000': 74.59%
# Number of rows after cleaning: 138
# Data cleaning complete. Number of rows after cleaning and filling: 2923
# Finished processing: ../../data/original_data/appears/ndvi/NWP61001.csv
# Processing file: ../../data/original_data/appears/ndvi/NWP45001.csv
# Percentage of rows with value '0b00000000000000000000000000000000': 77.84%
# Number of rows after cleaning: 144
# Data cleaning complete. Number of rows after cleaning and filling: 2923
# Finished processing: ../../data/original_data/appears/ndvi/NWP45001.csv
# Processing file: ../../data/original_data/appears/ndvi/NWP20004.csv
# Percentage of rows with value '0b00000000000000000000000000000000': 75.68%
# Number of rows after cleaning: 140
# Data cleaning complete. Number of rows after cleaning and filling: 2923
# Finished processing: ../../data/original_data/appears/ndvi/NWP20004.csv
# Processing file: ../../data/original_data/appears/ndvi/0000020005.csv
# Percentage of rows with value '0b00000000000000000000000000000000': 69.73%
# Number of rows after cleaning: 129
# Data cleaning complete. Number of rows after cleaning and filling: 2923
# Finished processing: ../../data/original_data/appears/ndvi/0000020005.csv
# Processing file: ../../data/original_data/appears/ndvi/NWP22001.csv
# Percentage of rows with value '0b00000000000000000000000000000000': 67.57%
# Number of rows after cleaning: 125
# Data cleaning complete. Number of rows after cleaning and filling: 2923
# Finished processing: ../../data/original_data/appears/ndvi/NWP22001.csv
# Processing file: ../../data/original_data/appears/ndvi/0000022001.csv
# Percentage of rows with value '0b00000000000000000000000000000000': 67.57%
# Number of rows after cleaning: 125
# Data cleaning complete. Number of rows after cleaning and filling: 2923
# Finished processing: ../../data/original_data/appears/ndvi/0000022001.csv
# Processing file: ../../data/original_data/appears/ndvi/NWP20005.csv
# Percentage of rows with value '0b00000000000000000000000000000000': 69.73%
# Number of rows after cleaning: 129
# Data cleaning complete. Number of rows after cleaning and filling: 2923
# Finished processing: ../../data/original_data/appears/ndvi/NWP20005.csv
# Processing file: ../../data/original_data/appears/ndvi/NWP20007.csv
# Percentage of rows with value '0b00000000000000000000000000000000': 71.89%
# Number of rows after cleaning: 133
# Data cleaning complete. Number of rows after cleaning and filling: 2923
# Finished processing: ../../data/original_data/appears/ndvi/NWP20007.csv
# Processing file: ../../data/original_data/appears/ndvi/0000020006.csv
# Percentage of rows with value '0b00000000000000000000000000000000': 64.86%
# Number of rows after cleaning: 120
# Data cleaning complete. Number of rows after cleaning and filling: 2923
# Finished processing: ../../data/original_data/appears/ndvi/0000020006.csv
# Processing file: ../../data/original_data/appears/ndvi/tasks_ndvi_wells_gambia.csv
# KeyError encountered in file ../../data/original_data/appears/ndvi/tasks_ndvi_wells_gambia.csv: 'MOD13Q1_061__250m_16_days_pixel_reliability_MODLAND'
# Finished processing: ../../data/original_data/appears/ndvi/tasks_ndvi_wells_gambia.csv
# Processing file: ../../data/original_data/appears/ndvi/NWP22002.csv
# Percentage of rows with value '0b00000000000000000000000000000000': 69.73%
# Number of rows after cleaning: 129
# Data cleaning complete. Number of rows after cleaning and filling: 2923
# Finished processing: ../../data/original_data/appears/ndvi/NWP22002.csv
# Processing file: ../../data/original_data/appears/ndvi/NWP22003.csv
# Percentage of rows with value '0b00000000000000000000000000000000': 69.73%
# Number of rows after cleaning: 129
# Data cleaning complete. Number of rows after cleaning and filling: 2923
# Finished processing: ../../data/original_data/appears/ndvi/NWP22003.csv
# Processing file: ../../data/original_data/appears/ndvi/0000020007.csv
# Percentage of rows with value '0b00000000000000000000000000000000': 71.89%
# Number of rows after cleaning: 133
# Data cleaning complete. Number of rows after cleaning and filling: 2923
# Finished processing: ../../data/original_data/appears/ndvi/0000020007.csv
# Processing file: ../../data/original_data/appears/ndvi/NWP20006.csv
# Percentage of rows with value '0b00000000000000000000000000000000': 64.86%
# Number of rows after cleaning: 120
# Data cleaning complete. Number of rows after cleaning and filling: 2923
# Finished processing: ../../data/original_data/appears/ndvi/NWP20006.csv
# Processing file: ../../data/original_data/appears/ndvi/NWP20002.csv
# Percentage of rows with value '0b00000000000000000000000000000000': 49.19%
# Number of rows after cleaning: 91
# Data cleaning complete. Number of rows after cleaning and filling: 2923
# Finished processing: ../../data/original_data/appears/ndvi/NWP20002.csv
# Processing file: ../../data/original_data/appears/ndvi/NWP20003.csv
# Percentage of rows with value '0b00000000000000000000000000000000': 67.03%
# Number of rows after cleaning: 124
# Data cleaning complete. Number of rows after cleaning and filling: 2923
# Finished processing: ../../data/original_data/appears/ndvi/NWP20003.csv
# Processing file: ../../data/original_data/appears/ndvi/NWP43001.csv
# Percentage of rows with value '0b00000000000000000000000000000000': 72.97%
# Number of rows after cleaning: 135
# Data cleaning complete. Number of rows after cleaning and filling: 2923
# Finished processing: ../../data/original_data/appears/ndvi/NWP43001.csv
# Processing file: ../../data/original_data/appears/ndvi/NWP51001.csv
# Percentage of rows with value '0b00000000000000000000000000000000': 79.46%
# Number of rows after cleaning: 147
# Data cleaning complete. Number of rows after cleaning and filling: 2923
# Finished processing: ../../data/original_data/appears/ndvi/NWP51001.csv
# Processing file: ../../data/original_data/appears/ndvi/NWP20025.csv
# Percentage of rows with value '0b00000000000000000000000000000000': 61.62%
# Number of rows after cleaning: 114
# Data cleaning complete. Number of rows after cleaning and filling: 2923
# Finished processing: ../../data/original_data/appears/ndvi/NWP20025.csv
# Processing file: ../../data/original_data/appears/ndvi/NWP54001.csv
# Percentage of rows with value '0b00000000000000000000000000000000': 78.92%
# Number of rows after cleaning: 146
# Data cleaning complete. Number of rows after cleaning and filling: 2923
# Finished processing: ../../data/original_data/appears/ndvi/NWP54001.csv
# Processing file: ../../data/original_data/appears/ndvi/NWP58001.csv
# Percentage of rows with value '0b00000000000000000000000000000000': 79.46%
# Number of rows after cleaning: 147
# Data cleaning complete. Number of rows after cleaning and filling: 2923
# Finished processing: ../../data/original_data/appears/ndvi/NWP58001.csv
# Processing file: ../../data/original_data/appears/ndvi/NWP13001.csv
# Percentage of rows with value '0b00000000000000000000000000000000': 45.41%
# Number of rows after cleaning: 84
# Data cleaning complete. Number of rows after cleaning and filling: 2923
# Finished processing: ../../data/original_data/appears/ndvi/NWP13001.csv
# Processing file: ../../data/original_data/appears/ndvi/0000058001.csv
# Percentage of rows with value '0b00000000000000000000000000000000': 79.46%
# Number of rows after cleaning: 147
# Data cleaning complete. Number of rows after cleaning and filling: 2923
# Finished processing: ../../data/original_data/appears/ndvi/0000058001.csv
# Processing file: ../../data/original_data/appears/ndvi/NWP62001.csv
# Percentage of rows with value '0b00000000000000000000000000000000': 72.43%
# Number of rows after cleaning: 134
# Data cleaning complete. Number of rows after cleaning and filling: 2923
# Finished processing: ../../data/original_data/appears/ndvi/NWP62001.csv
# Processing file: ../../data/original_data/appears/ndvi/NWP20024.csv
# Percentage of rows with value '0b00000000000000000000000000000000': 65.41%
# Number of rows after cleaning: 121
# Data cleaning complete. Number of rows after cleaning and filling: 2923
# Finished processing: ../../data/original_data/appears/ndvi/NWP20024.csv
# Processing file: ../../data/original_data/appears/ndvi/NWP54002.csv
# Percentage of rows with value '0b00000000000000000000000000000000': 75.68%
# Number of rows after cleaning: 140
# Data cleaning complete. Number of rows after cleaning and filling: 2923
# Finished processing: ../../data/original_data/appears/ndvi/NWP54002.csv
# Processing file: ../../data/original_data/appears/ndvi/NWP58002.csv
# Percentage of rows with value '0b00000000000000000000000000000000': 77.84%
# Number of rows after cleaning: 144
# Data cleaning complete. Number of rows after cleaning and filling: 2923
# Finished processing: ../../data/original_data/appears/ndvi/NWP58002.csv
# Processing file: ../../data/original_data/appears/ndvi/NWP62002.csv
# Percentage of rows with value '0b00000000000000000000000000000000': 74.59%
# Number of rows after cleaning: 138
# Data cleaning complete. Number of rows after cleaning and filling: 2923
# Finished processing: ../../data/original_data/appears/ndvi/NWP62002.csv
# Processing file: ../../data/original_data/appears/ndvi/NWP20023.csv
# Percentage of rows with value '0b00000000000000000000000000000000': 61.62%
# Number of rows after cleaning: 114
# Data cleaning complete. Number of rows after cleaning and filling: 2923
# Finished processing: ../../data/original_data/appears/ndvi/NWP20023.csv
# Processing file: ../../data/original_data/appears/ndvi/NWP20008.csv
# Percentage of rows with value '0b00000000000000000000000000000000': 74.05%
# Number of rows after cleaning: 137
# Data cleaning complete. Number of rows after cleaning and filling: 2923
# Finished processing: ../../data/original_data/appears/ndvi/NWP20008.csv
# Processing file: ../../data/original_data/appears/ndvi/NWP27001.csv
# Percentage of rows with value '0b00000000000000000000000000000000': 71.35%
# Number of rows after cleaning: 132
# Data cleaning complete. Number of rows after cleaning and filling: 2923
# Finished processing: ../../data/original_data/appears/ndvi/NWP27001.csv
# Processing file: ../../data/original_data/appears/ndvi/0000020009.csv
# Percentage of rows with value '0b00000000000000000000000000000000': 75.68%
# Number of rows after cleaning: 140
# Data cleaning complete. Number of rows after cleaning and filling: 2923
# Finished processing: ../../data/original_data/appears/ndvi/0000020009.csv
# Processing file: ../../data/original_data/appears/ndvi/NWP35001.csv
# Percentage of rows with value '0b00000000000000000000000000000000': 79.46%
# Number of rows after cleaning: 147
# Data cleaning complete. Number of rows after cleaning and filling: 2923
# Finished processing: ../../data/original_data/appears/ndvi/NWP35001.csv
# Processing file: ../../data/original_data/appears/ndvi/NWP58011.csv
# Percentage of rows with value '0b00000000000000000000000000000000': 75.14%
# Number of rows after cleaning: 139
# Data cleaning complete. Number of rows after cleaning and filling: 2923
# Finished processing: ../../data/original_data/appears/ndvi/NWP58011.csv
# Processing file: ../../data/original_data/appears/ndvi/0000035001.csv
# Percentage of rows with value '0b00000000000000000000000000000000': 79.46%
# Number of rows after cleaning: 147
# Data cleaning complete. Number of rows after cleaning and filling: 2923
# Finished processing: ../../data/original_data/appears/ndvi/0000035001.csv
# Processing file: ../../data/original_data/appears/ndvi/NWP60001.csv
# Percentage of rows with value '0b00000000000000000000000000000000': 77.30%
# Number of rows after cleaning: 143
# Data cleaning complete. Number of rows after cleaning and filling: 2923
# Finished processing: ../../data/original_data/appears/ndvi/NWP60001.csv
# Processing file: ../../data/original_data/appears/ndvi/NWP20009.csv
# Percentage of rows with value '0b00000000000000000000000000000000': 75.68%
# Number of rows after cleaning: 140
# Data cleaning complete. Number of rows after cleaning and filling: 2923
# Finished processing: ../../data/original_data/appears/ndvi/NWP20009.csv
# Processing file: ../../data/original_data/appears/ndvi/0000023001.csv
# Percentage of rows with value '0b00000000000000000000000000000000': 72.43%
# Number of rows after cleaning: 134
# Data cleaning complete. Number of rows after cleaning and filling: 2923
# Finished processing: ../../data/original_data/appears/ndvi/0000023001.csv
# Processing file: ../../data/original_data/appears/ndvi/NWP31001.csv
# Percentage of rows with value '0b00000000000000000000000000000000': 76.22%
# Number of rows after cleaning: 141
# Data cleaning complete. Number of rows after cleaning and filling: 2923
# Finished processing: ../../data/original_data/appears/ndvi/NWP31001.csv
# Processing file: ../../data/original_data/appears/ndvi/NWP23001.csv
# Percentage of rows with value '0b00000000000000000000000000000000': 72.43%
# Number of rows after cleaning: 134
# Data cleaning complete. Number of rows after cleaning and filling: 2923
# Finished processing: ../../data/original_data/appears/ndvi/NWP23001.csv
# Processing file: ../../data/original_data/appears/ndvi/NWP40001.csv
# Percentage of rows with value '0b00000000000000000000000000000000': 69.19%
# Number of rows after cleaning: 128
# Data cleaning complete. Number of rows after cleaning and filling: 2923
# Finished processing: ../../data/original_data/appears/ndvi/NWP40001.csv
# Processing file: ../../data/original_data/appears/ndvi/NWP50001.csv
# Percentage of rows with value '0b00000000000000000000000000000000': 83.78%
# Number of rows after cleaning: 155
# Data cleaning complete. Number of rows after cleaning and filling: 2923
# Finished processing: ../../data/original_data/appears/ndvi/NWP50001.csv
# Processing file: ../../data/original_data/appears/ndvi/NWP33001.csv
# Percentage of rows with value '0b00000000000000000000000000000000': 77.84%
# Number of rows after cleaning: 144
# Data cleaning complete. Number of rows after cleaning and filling: 2923
# Finished processing: ../../data/original_data/appears/ndvi/NWP33001.csv
# Processing file: ../../data/original_data/appears/ndvi/NWP21002.csv
# Percentage of rows with value '0b00000000000000000000000000000000': 60.54%
# Number of rows after cleaning: 112
# Data cleaning complete. Number of rows after cleaning and filling: 2923
# Finished processing: ../../data/original_data/appears/ndvi/NWP21002.csv

# %% [markdown]
# ### Then we merged with the master dataset containing the information of the differents wells and the groundwater level over the time (between 2015 and 2022). We delete all the rows that has same well and same day. Reducing the dataset from 25406 rows to 6636. Basically some wells take information in the same day more than 1 time (2,3,4) and for this project we are using a daily time-space.

# %%
main_df_path = '../../data/processed_data/merged_data_gambia.csv'
additional_data_dir = '../../data/processed_data/appears/ndvi/'
merged_df = merge_additional_data(main_df_path, additional_data_dir)
# Out:
# Initial number of rows in main dataframe: 25406
# Number of rows in final dataframe: 6636

# %%
# Specify the columns you want to drop
columns_to_drop = ['Latitude_y', 'Longitude_y']

# Use the drop() method to remove the specified columns
merged_df = merged_df.drop(columns=columns_to_drop)

# %%
# Create a dictionary to specify the column name changes
column_name_changes = {
    'Latitude_x': 'Latitude',
    'Longitude_x': 'Longitude'
}

# Use the rename() method to rename the specified columns
merged_df = merged_df.rename(columns=column_name_changes)

# %%
merged_df
# Out:
#              ID  GROUNDWATER_LEVEL  Day  Month  Year   Latitude  Longitude  \
# 0      NWP00001              14.26   14      4  2016  13.420804 -16.716666
# 1      NWP00001              13.82   26     12  2015  13.420804 -16.716666
# 3      NWP00001              13.82   25     12  2015  13.420804 -16.716666
# 7      NWP00001              13.83   24     12  2015  13.420804 -16.716666
# 11     NWP00001              13.83   23     12  2015  13.420804 -16.716666
# ...         ...                ...  ...    ...   ...        ...        ...
# 25387  NWP21002              16.85    5      1  2015  13.240281 -16.713889
# 25391  NWP21002              16.79    4      1  2015  13.240281 -16.713889
# 25395  NWP21002              16.82    3      1  2015  13.240281 -16.713889
# 25399  NWP21002              16.82    2      1  2015  13.240281 -16.713889
# 25403  NWP21002              16.81    1      1  2015  13.240281 -16.713889
#
#        Ground surface elevation  LIS_Soil_Moisture_Combined  LIS_Streamflow  \
# 0                         19.47                    0.172124        0.059371
# 1                         19.47                    0.210837        0.136391
# 3                         19.47                    0.211614        0.138738
# 7                         19.47                    0.212448        0.141231
# 11                        19.47                    0.213260        0.143826
# ...                         ...                         ...             ...
# 25387                     21.68                    0.232334        0.085506
# 25391                     21.68                    0.232903        0.086226
# 25395                     21.68                    0.233475        0.086970
# 25399                     21.68                    0.234051        0.087731
# 25403                     21.68                    0.234645        0.088509
#
#          LIS_ET       Date  MOD13Q1_061__250m_16_days_EVI  \
# 0      0.219499 2016-04-14                         0.2113
# 1      1.412334 2015-12-26                         0.2443
# 3      1.612549 2015-12-25                         0.2443
# 7      1.522625 2015-12-24                         0.2443
# 11     1.481390 2015-12-23                         0.2443
# ...         ...        ...                            ...
# 25387  1.118654 2015-01-05                         0.1795
# 25391  1.095831 2015-01-04                         0.1795
# 25395  1.068498 2015-01-03                         0.1795
# 25399  1.069310 2015-01-02                         0.1795
# 25403  1.118614 2015-01-01                         0.1795
#
#        MOD13Q1_061__250m_16_days_MIR_reflectance  \
# 0                                         0.3972
# 1                                         0.1787
# 3                                         0.1787
# 7                                         0.1787
# 11                                        0.1787
# ...                                          ...
# 25387                                     0.2054
# 25391                                     0.2054
# 25395                                     0.2054
# 25399                                     0.2054
# 25403                                     0.2054
#
#        MOD13Q1_061__250m_16_days_NDVI
# 0                              0.2564
# 1                              0.4064
# 3                              0.4064
# 7                              0.4064
# 11                             0.4064
# ...                               ...
# 25387                          0.3419
# 25391                          0.3419
# 25395                          0.3419
# 25399                          0.3419
# 25403                          0.3419
#
# [6636 rows x 15 columns]

# %%
csv_path = '../../data/processed_data/final_data_gambia.csv'
merged_df.to_csv(csv_path, index=False)  # Set index to False if you don't want to save the DataFrame index

# %% [markdown]
# ### Finally we have merged into our dataset 3 variables coming from AppEARS: NDVI, EVI and MIR reflectance.
